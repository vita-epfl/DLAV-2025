# %% [markdown]
# ## Convolutional Networks
#
# We'll check out how to build a **convolutional network** to classify CIFAR10 images. By using weight sharing - multiple units with the same weights - convolutional layers are able to learn repeated patterns in your data. For example, a unit could learn the pattern for an eye, or a face, or lower level features like edges.

# %%
import numpy as np
import time

import torch
from torch import nn
from torch import optim
import torch.nn.functional as F
import torch.utils.data as utils
from torchvision import datasets, transforms
from torch.utils.data.sampler import SubsetRandomSampler
import matplotlib.pyplot as plt
import torchvision.utils as vutils
from torchvision.datasets import CIFAR10

# %matplotlib inline

# %%
label_names = [
    'airplane',
    'automobile',
    'bird',
    'cat',
    'deer',
    'dog',
    'frog',
    'horse',
    'ship',
    'truck'
]


def plot_images(images, cls_true, cls_pred=None):
    """
    Adapted from https://github.com/Hvass-Labs/TensorFlow-Tutorials/
    """
    fig, axes = plt.subplots(3, 3)

    for i, ax in enumerate(axes.flat):
        # plot img
        ax.imshow(images[i, :, :, :], interpolation='spline16')

        # show true & predicted classes
        cls_true_name = label_names[cls_true[i]]
        if cls_pred is None:
            xlabel = "{0} ({1})".format(cls_true_name, cls_true[i])
        else:
            cls_pred_name = label_names[cls_pred[i]]
            xlabel = "True: {0}\nPred: {1}".format(
                cls_true_name, cls_pred_name
            )
        ax.set_xlabel(xlabel)
        ax.set_xticks([])
        ax.set_yticks([])

    plt.show()

# %%
def get_train_valid_loader(data_dir='data',
                           batch_size=64,
                           augment=False,
                           random_seed=1,
                           valid_size=0.02,
                           shuffle=True,
                           show_sample=True,
                           num_workers=4,
                           pin_memory=False):
    """
    Utility function for loading and returning train and valid
    multi-process iterators over the CIFAR-10 dataset. A sample
    9x9 grid of the images can be optionally displayed.
    If using CUDA, num_workers should be set to 1 and pin_memory to True.
    Params
    ------
    - data_dir: path directory to the dataset.
    - batch_size: how many samples per batch to load.
    - augment: whether to apply the data augmentation scheme
      mentioned in the paper. Only applied on the train split.
    - random_seed: fix seed for reproducibility.
    - valid_size: percentage split of the training set used for
      the validation set. Should be a float in the range [0, 1].
    - shuffle: whether to shuffle the train/validation indices.
    - show_sample: plot 9x9 sample grid of the dataset.
    - num_workers: number of subprocesses to use when loading the dataset.
    - pin_memory: whether to copy tensors into CUDA pinned memory. Set it to
      True if using GPU.
    Returns
    -------
    - train_loader: training set iterator.
    - valid_loader: validation set iterator.
    """
    error_msg = "[!] valid_size should be in the range [0, 1]."
    assert ((valid_size >= 0) and (valid_size <= 1)), error_msg

    normalize = transforms.Normalize(
        mean=[0.4914, 0.4822, 0.4465],
        std=[0.2023, 0.1994, 0.2010],
    )

    # define transforms for validation (no augmentation)
    valid_transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.RandomHorizontalFlip(),
        transforms.RandomGrayscale(),
        transforms.RandomRotation(10),
        normalize,
    ])

    # Define the transform for training (and data augmentation)

    train_transform = transforms.Compose([
        transforms.ToTensor(),
        normalize,
    ])

    # load the dataset
    train_dataset = datasets.CIFAR10(
        root=data_dir, train=True,
        download=True, transform=train_transform,
    )

    valid_dataset = datasets.CIFAR10(
        root=data_dir, train=True,
        download=True, transform=valid_transform,
    )

    num_train = len(train_dataset)
    indices = list(range(num_train))
    split = int(np.floor(valid_size * num_train))

    if shuffle:
        np.random.seed(random_seed)
        np.random.shuffle(indices)

    train_idx, valid_idx = indices[split:], indices[:split]
    train_sampler = SubsetRandomSampler(train_idx)
    valid_sampler = SubsetRandomSampler(valid_idx)

    train_loader = torch.utils.data.DataLoader(
        train_dataset, batch_size=batch_size, sampler=train_sampler,
        num_workers=num_workers, pin_memory=pin_memory,
    )
    valid_loader = torch.utils.data.DataLoader(
        valid_dataset, batch_size=batch_size, sampler=valid_sampler,
        num_workers=num_workers, pin_memory=pin_memory,
    )

    # visualize some images if requested
    if show_sample:
        sample_loader = torch.utils.data.DataLoader(
            train_dataset, batch_size=9, shuffle=shuffle,
            num_workers=num_workers, pin_memory=pin_memory,
        )
        data_iter = iter(sample_loader)
        images, labels = next(data_iter)
        # Unnormalize the images for display
        mean = [0.4914, 0.4822, 0.4465]
        std = [0.2023, 0.1994, 0.2010]
        unnorm_images = [unnormalize(img, mean, std) for img in images]
        X = torch.stack(unnorm_images).numpy().transpose([0, 2, 3, 1])
        plot_images(X, labels)

    return (train_loader, valid_loader)

def unnormalize(img, mean, std):
    img = img * torch.tensor(std).view(3, 1, 1) + torch.tensor(mean).view(3, 1, 1)
    return img

trainloader, valloader = get_train_valid_loader()

# %% [markdown]
# # Convolutional Neural Network Architecture

# %% [markdown]
# Please first review the CNN lecture and problem statement pdf to understand the overall architecture of a CNN and how each dimension evolves after each layer, we'll take as example the first and famous CNN LeNet5 :
# <figure align="center">
#   <img src="https://doimages.nyc3.cdn.digitaloceanspaces.com/010AI-ML/content/images/2021/10/image-17.png" alt="LeNet5 Architecture" width="600">
#   <figcaption>Image credit: <a href="https://en.wikipedia.org">Wikipedia</a></figcaption>
# </figure>

# %% [markdown]
# # **Theory - Part 1 (20%)**
#
# Please answer the following questions to assess your understanding of what happens during the training and inference of a CNN.
#
# If you find any of these questions challenging or have any doubts, feel free to ask a TA for guidance or hints on the solution.

# %% [markdown]
# ## 1. First Layer Convolution
#
# If we consider the input of LeNet5 to be CIFAR-10, what would be the shape of the parameters of the first convolutional layer (stride = 1)?
#
# - **A.** `torch.Size([6, 1, 5, 5])`
# - **B.** `torch.Size([6, 3, 3, 3])`
# - **C.** `torch.Size([6, 1, 5, 5])`
# - **D.** `torch.Size([6, 3, 5, 5])`

# %% [markdown]
# ## Ans1: D

# %% [markdown]
# ## 2. Subsampling Window
#
# What is the shape of the subsampling window (stride = 2) for the second layer (between C1 and C2), and does this shape remain invariant regardless of the subsampling method (e.g., Avg pooling or Max pooling)?
#
# - **A.** `2x2, yes it does`
# - **B.** `3x3, no it doesn't`
# - **C.** `2x2, no it doesn't`
# - **D.** `yes, it does`

# %% [markdown]
# ## Ans2: A

# %% [markdown]
# ## 3. Backpropagation for Convolutional Filters
#
# Do the filters in the convolutional layers also benefit from backpropagation?

# %% [markdown]
# ## Ans3: Yes

# %% [markdown]
# ## 4. Role of the Fully-Connected Layer
#
# Explain in your own words why it is necessary to have a fully-connected layer in the architecture.

# %% [markdown]
# ## Ans4:
# The fully connected layer is necessary to combine the features extracted by the convolutional layers and to make the final decision about the class of the input image.

# %% [markdown]
# # **Coding(60%)**
#
# ## Build your own Convolutional Neural Network Architecture

# %% [markdown]
# ## Different ways to improve the accuracy of your network :
# - Change the number of convolutions and layers (you can take inspiration from internet as you as you cite the architecture)
# - Change the optmizer / its hyperparameters
# - Add new types of layers
# - Do some data augmentation in the get_train_valid_loader function (flipped, cropped, uncentered images) cf. https://pytorch.org/vision/stable/transforms.html

# %%
class ConvNet(nn.Module):
    def __init__(self, n_input_channels=3, n_output=10):
        super().__init__()
        ################################################################################
        # TODO:                                                                        #
        # Define 2 or more different layers of the neural network                      #
        ################################################################################

        ## Inspired from https://www.kaggle.com/code/ektasharma/simple-cifar10-cnn-keras-code-with-88-accuracy

        self.conv1 = nn.Conv2d(n_input_channels, 32, kernel_size=3, padding=1)
        self.bnn1 = nn.BatchNorm2d(32)
        self.conv2 = nn.Conv2d(32, 32, kernel_size=3, padding=1)
        self.bnn2 = nn.BatchNorm2d(32)
        self.pool1 = nn.MaxPool2d(2, 2)

        self.conv3 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.bnn3 = nn.BatchNorm2d(64)
        self.conv4 = nn.Conv2d(64, 64, kernel_size=3, padding=1)
        self.bnn4 = nn.BatchNorm2d(64)
        self.pool2 = nn.MaxPool2d(2, 2)

        self.conv5 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.bnn5 = nn.BatchNorm2d(128)
        self.conv6 = nn.Conv2d(128, 128, kernel_size=3, padding=1)
        self.bnn6 = nn.BatchNorm2d(128)
        self.pool3 = nn.MaxPool2d(2, 2)

        self.fc1 = nn.Linear(128*4*4, 128)
        self.fc2 = nn.Linear(128, n_output)
        self.logsoftmax = nn.LogSoftmax(dim=1)
        '''
        '''
        ################################################################################
        #                              END OF YOUR CODE                                #
        ################################################################################

    def forward(self, x):
        ################################################################################
        # TODO:                                                                        #
        # Set up the forward pass that the input data will go through.                 #
        # A good activation function betweent the layers is a ReLu function.           #
        #                                                                              #
        # Note that the output of the last convolution layer should be flattened       #
        # before being inputted to the fully connected layer. We can flatten           #
        # Tensor `x` with `x.view`.                                                    #
        ###############################################################################

        '''
        x = F.relu(self.conv1(x))
        x = self.pool1(x)
        x = F.relu(self.conv2(x))
        x = self.pool2(x)   
        x = F.relu(self.conv3(x))
        x = self.pool3(x)
        x = F.relu(self.conv4(x))
        x = self.pool4(x)
        x = torch.flatten(x, 1)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        output = self.logsoftmax(x)
        return output

        '''
        x = F.relu(self.conv1(x))
        x = self.bnn1(x)
        x = F.relu(self.conv2(x))
        x = self.bnn2(x)
        x = self.pool1(x)
        x = F.relu(self.conv3(x))
        x = self.bnn3(x)
        x = F.relu(self.conv4(x))
        x = self.bnn4(x)
        x = self.pool2(x)
        x = F.relu(self.conv5(x))
        x = self.bnn5(x)
        x = F.relu(self.conv6(x))
        x = self.bnn6(x)
        x = self.pool3(x)
        x = torch.flatten(x, 1)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x
        ################################################################################
        #                              END OF YOUR CODE                                #
        ################################################################################

        return x

    def predict(self, x):
        logits = self.forward(x)
        return F.softmax(logits)

# %%
import torch.optim


net = ConvNet()
################################################################################
# TODO:                                                                        #
# Choose an Optimizer that will be used to minimize the loss function.         #
# Choose a critera that measures the loss                                      #
################################################################################
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(net.parameters())

epochs = 15
steps = 0
running_loss = 0
print_every = 20
for e in range(epochs):
    start = time.time()
    for images, labels in iter(trainloader):

        steps += 1
        ################################################################################
        # TODO:                                                                        #
        # Run the training process                                                     #
        #                                                                              #
        #                                                                              #
        ################################################################################
        output = net(images)
        targets = labels
        ################################################################################
        #                              END OF YOUR CODE                                #
        ################################################################################

        loss = criterion(output, targets)
        ################################################################################
        # TODO:                                                                        #
        # Run the training process                                                     #
        #                                                                              #
        # HINT: Calculate the gradient and move one step further                       #
        ################################################################################
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        ################################################################################
        #                              END OF YOUR CODE                                #
        ################################################################################

        running_loss += loss.item()

        if steps % print_every == 0:
            stop = time.time()
            # Test accuracy
            accuracy = 0
            for ii, (images, labels) in enumerate(valloader):

                ################################################################################
                # TODO:                                                                        #
                # Calculate the accuracy                                                       #
                ################################################################################
                output = net(images)
                accuracy += torch.sum(torch.argmax(output, dim=1) == labels).item()
                ################################################################################
                #                              END OF YOUR CODE                                #
                ################################################################################

            print("Epoch: {}/{}..".format(e+1, epochs),
                  "Loss: {:.4f}..".format(running_loss/print_every),
                  "Test accuracy: {:.4f}..".format(accuracy/(ii+1)),
                  "{:.4f} s/batch".format((stop - start)/print_every)
                 )
            running_loss = 0
            start = time.time()
# Out:
# Epoch: 1/15.. Loss: 2.0099.. Test accuracy: 22.3750.. 0.3307 s/batch
# Epoch: 1/15.. Loss: 1.6710.. Test accuracy: 23.5625.. 0.3797 s/batch
# Epoch: 1/15.. Loss: 1.6284.. Test accuracy: 25.5000.. 0.4150 s/batch
# Epoch: 1/15.. Loss: 1.4880.. Test accuracy: 28.0625.. 0.7830 s/batch
# Epoch: 1/15.. Loss: 1.4571.. Test accuracy: 27.3750.. 0.5174 s/batch
# Epoch: 1/15.. Loss: 1.3956.. Test accuracy: 27.6250.. 0.3154 s/batch
# Epoch: 1/15.. Loss: 1.3765.. Test accuracy: 30.2500.. 0.2721 s/batch
# Epoch: 1/15.. Loss: 1.2702.. Test accuracy: 32.6875.. 0.3288 s/batch
# Epoch: 1/15.. Loss: 1.3006.. Test accuracy: 31.8125.. 0.3268 s/batch
# Epoch: 1/15.. Loss: 1.2711.. Test accuracy: 34.2500.. 0.2539 s/batch
# Epoch: 1/15.. Loss: 1.1665.. Test accuracy: 34.0625.. 0.3182 s/batch
# Epoch: 1/15.. Loss: 1.1555.. Test accuracy: 33.5000.. 0.3353 s/batch
# Epoch: 1/15.. Loss: 1.1598.. Test accuracy: 35.3125.. 0.2810 s/batch
# Epoch: 1/15.. Loss: 1.1109.. Test accuracy: 36.1875.. 0.3553 s/batch
# Epoch: 1/15.. Loss: 1.0963.. Test accuracy: 34.5000.. 0.3128 s/batch
# Epoch: 1/15.. Loss: 1.0943.. Test accuracy: 37.3750.. 0.4466 s/batch
# Epoch: 1/15.. Loss: 0.9869.. Test accuracy: 39.0625.. 0.3951 s/batch
# Epoch: 1/15.. Loss: 1.0330.. Test accuracy: 38.5625.. 0.3175 s/batch
# Epoch: 1/15.. Loss: 1.0089.. Test accuracy: 38.1875.. 0.2990 s/batch
# Epoch: 1/15.. Loss: 0.9907.. Test accuracy: 37.5000.. 0.2974 s/batch
# Epoch: 1/15.. Loss: 0.9677.. Test accuracy: 39.1250.. 0.3739 s/batch
# Epoch: 1/15.. Loss: 0.9699.. Test accuracy: 39.6875.. 0.3367 s/batch
# Epoch: 1/15.. Loss: 0.9448.. Test accuracy: 39.3750.. 0.3321 s/batch
# Epoch: 1/15.. Loss: 0.9432.. Test accuracy: 37.0625.. 0.3196 s/batch
# Epoch: 1/15.. Loss: 0.9005.. Test accuracy: 38.0000.. 0.2710 s/batch
# Epoch: 1/15.. Loss: 0.9335.. Test accuracy: 37.1875.. 0.3044 s/batch
# Epoch: 1/15.. Loss: 0.9618.. Test accuracy: 40.5000.. 0.3360 s/batch
# Epoch: 1/15.. Loss: 0.8871.. Test accuracy: 39.4375.. 0.0967 s/batch
# Epoch: 1/15.. Loss: 0.8686.. Test accuracy: 40.6250.. 0.1055 s/batch
# Epoch: 1/15.. Loss: 0.8844.. Test accuracy: 40.1250.. 0.0976 s/batch
# Epoch: 1/15.. Loss: 0.8360.. Test accuracy: 40.4375.. 0.0945 s/batch
# Epoch: 1/15.. Loss: 0.8702.. Test accuracy: 41.0000.. 0.1229 s/batch
# Epoch: 1/15.. Loss: 0.9054.. Test accuracy: 40.0000.. 0.1622 s/batch
# Epoch: 1/15.. Loss: 0.8279.. Test accuracy: 42.1250.. 0.1298 s/batch
# Epoch: 1/15.. Loss: 0.8310.. Test accuracy: 41.2500.. 0.1511 s/batch
# Epoch: 1/15.. Loss: 0.8593.. Test accuracy: 41.4375.. 0.1107 s/batch
# Epoch: 1/15.. Loss: 0.7931.. Test accuracy: 41.2500.. 0.1285 s/batch
# Epoch: 1/15.. Loss: 0.7944.. Test accuracy: 41.6875.. 0.1005 s/batch
# Epoch: 2/15.. Loss: 0.7339.. Test accuracy: 43.5000.. 0.0994 s/batch
# Epoch: 2/15.. Loss: 0.6706.. Test accuracy: 43.7500.. 0.1071 s/batch
# Epoch: 2/15.. Loss: 0.7445.. Test accuracy: 42.8125.. 0.0975 s/batch
# Epoch: 2/15.. Loss: 0.7441.. Test accuracy: 42.3750.. 0.1048 s/batch
# Epoch: 2/15.. Loss: 0.6952.. Test accuracy: 42.5000.. 0.0967 s/batch
# Epoch: 2/15.. Loss: 0.6807.. Test accuracy: 43.1250.. 0.0945 s/batch
# Epoch: 2/15.. Loss: 0.6818.. Test accuracy: 43.5625.. 0.1021 s/batch
# Epoch: 2/15.. Loss: 0.6557.. Test accuracy: 42.2500.. 0.0978 s/batch
# Epoch: 2/15.. Loss: 0.7078.. Test accuracy: 42.5000.. 0.1082 s/batch
# Epoch: 2/15.. Loss: 0.6830.. Test accuracy: 43.1875.. 0.1295 s/batch
# Epoch: 2/15.. Loss: 0.7528.. Test accuracy: 43.7500.. 0.1074 s/batch
# Epoch: 2/15.. Loss: 0.6704.. Test accuracy: 43.7500.. 0.1318 s/batch
# Epoch: 2/15.. Loss: 0.6685.. Test accuracy: 43.5625.. 0.1141 s/batch
# Epoch: 2/15.. Loss: 0.7002.. Test accuracy: 42.3750.. 0.1093 s/batch
# Epoch: 2/15.. Loss: 0.6056.. Test accuracy: 43.0000.. 0.1132 s/batch
# Epoch: 2/15.. Loss: 0.6937.. Test accuracy: 43.8125.. 0.1384 s/batch
# Epoch: 2/15.. Loss: 0.7034.. Test accuracy: 44.6250.. 0.1395 s/batch
# Epoch: 2/15.. Loss: 0.6914.. Test accuracy: 44.8750.. 0.1453 s/batch
# Epoch: 2/15.. Loss: 0.6507.. Test accuracy: 43.5000.. 0.1505 s/batch
# Epoch: 2/15.. Loss: 0.6925.. Test accuracy: 45.0625.. 0.3058 s/batch
# Epoch: 2/15.. Loss: 0.6755.. Test accuracy: 43.7500.. 0.3067 s/batch
# Epoch: 2/15.. Loss: 0.6917.. Test accuracy: 42.3750.. 0.3902 s/batch
# Epoch: 2/15.. Loss: 0.6672.. Test accuracy: 45.6875.. 0.3388 s/batch
# Epoch: 2/15.. Loss: 0.6623.. Test accuracy: 43.3750.. 0.3551 s/batch
# Epoch: 2/15.. Loss: 0.6823.. Test accuracy: 43.0625.. 0.4271 s/batch
# Epoch: 2/15.. Loss: 0.6695.. Test accuracy: 44.0000.. 0.5913 s/batch
# Epoch: 2/15.. Loss: 0.6588.. Test accuracy: 45.1250.. 0.3455 s/batch
# Epoch: 2/15.. Loss: 0.6471.. Test accuracy: 45.9375.. 0.5183 s/batch
# Epoch: 2/15.. Loss: 0.6758.. Test accuracy: 43.4375.. 0.3007 s/batch
# Epoch: 2/15.. Loss: 0.6980.. Test accuracy: 44.2500.. 0.3300 s/batch
# Epoch: 2/15.. Loss: 0.6789.. Test accuracy: 45.1875.. 0.3691 s/batch
# Epoch: 2/15.. Loss: 0.6010.. Test accuracy: 44.9375.. 0.2765 s/batch
# Epoch: 2/15.. Loss: 0.6696.. Test accuracy: 44.8750.. 0.3744 s/batch
# Epoch: 2/15.. Loss: 0.6355.. Test accuracy: 43.4375.. 0.3721 s/batch
# Epoch: 2/15.. Loss: 0.6510.. Test accuracy: 45.1875.. 0.3805 s/batch
# Epoch: 2/15.. Loss: 0.6013.. Test accuracy: 46.1875.. 0.2509 s/batch
# Epoch: 2/15.. Loss: 0.6122.. Test accuracy: 45.6875.. 0.3005 s/batch
# Epoch: 2/15.. Loss: 0.6084.. Test accuracy: 45.5625.. 0.2999 s/batch
# Epoch: 3/15.. Loss: 0.5912.. Test accuracy: 44.2500.. 0.1349 s/batch
# Epoch: 3/15.. Loss: 0.5275.. Test accuracy: 46.0000.. 0.5212 s/batch
# Epoch: 3/15.. Loss: 0.4847.. Test accuracy: 45.7500.. 0.4381 s/batch
# Epoch: 3/15.. Loss: 0.4703.. Test accuracy: 45.3750.. 0.3732 s/batch
# Epoch: 3/15.. Loss: 0.5283.. Test accuracy: 44.8750.. 0.3191 s/batch
# Epoch: 3/15.. Loss: 0.5062.. Test accuracy: 46.3125.. 0.3645 s/batch
# Epoch: 3/15.. Loss: 0.5429.. Test accuracy: 45.2500.. 0.3379 s/batch
# Epoch: 3/15.. Loss: 0.5244.. Test accuracy: 45.4375.. 0.2931 s/batch
# Epoch: 3/15.. Loss: 0.5417.. Test accuracy: 45.7500.. 0.4199 s/batch
# Epoch: 3/15.. Loss: 0.4818.. Test accuracy: 46.6875.. 0.3236 s/batch
# Epoch: 3/15.. Loss: 0.5065.. Test accuracy: 45.3125.. 0.5094 s/batch
# Epoch: 3/15.. Loss: 0.4567.. Test accuracy: 46.1875.. 0.5108 s/batch
# Epoch: 3/15.. Loss: 0.5625.. Test accuracy: 44.0000.. 0.4943 s/batch
# Epoch: 3/15.. Loss: 0.5519.. Test accuracy: 45.1250.. 0.4929 s/batch
# Epoch: 3/15.. Loss: 0.5427.. Test accuracy: 46.9375.. 0.6197 s/batch
# Epoch: 3/15.. Loss: 0.4974.. Test accuracy: 45.3125.. 0.4045 s/batch
# Epoch: 3/15.. Loss: 0.5272.. Test accuracy: 45.0625.. 0.3793 s/batch
# Epoch: 3/15.. Loss: 0.5395.. Test accuracy: 46.1875.. 0.3897 s/batch
# Epoch: 3/15.. Loss: 0.5151.. Test accuracy: 45.4375.. 0.3306 s/batch
# Epoch: 3/15.. Loss: 0.5078.. Test accuracy: 44.8125.. 0.2784 s/batch
# Epoch: 3/15.. Loss: 0.5363.. Test accuracy: 46.5625.. 0.3315 s/batch
# Epoch: 3/15.. Loss: 0.4976.. Test accuracy: 44.9375.. 0.2664 s/batch
# Epoch: 3/15.. Loss: 0.5186.. Test accuracy: 46.5625.. 0.2689 s/batch
# Epoch: 3/15.. Loss: 0.5395.. Test accuracy: 45.5625.. 0.3322 s/batch
# Epoch: 3/15.. Loss: 0.5411.. Test accuracy: 45.1250.. 0.3434 s/batch
# Epoch: 3/15.. Loss: 0.4765.. Test accuracy: 46.7500.. 0.3735 s/batch
# Epoch: 3/15.. Loss: 0.4887.. Test accuracy: 46.2500.. 0.3761 s/batch
# Epoch: 3/15.. Loss: 0.4973.. Test accuracy: 45.2500.. 0.3723 s/batch
# Epoch: 3/15.. Loss: 0.4639.. Test accuracy: 46.6250.. 0.2378 s/batch
# Epoch: 3/15.. Loss: 0.5161.. Test accuracy: 47.3750.. 0.2485 s/batch
# Epoch: 3/15.. Loss: 0.4805.. Test accuracy: 46.3750.. 0.2386 s/batch
# Epoch: 3/15.. Loss: 0.5015.. Test accuracy: 46.8125.. 0.2104 s/batch
# Epoch: 3/15.. Loss: 0.4808.. Test accuracy: 46.0625.. 0.0950 s/batch
# Epoch: 3/15.. Loss: 0.4942.. Test accuracy: 46.1875.. 0.1207 s/batch
# Epoch: 3/15.. Loss: 0.4694.. Test accuracy: 47.0625.. 0.0931 s/batch
# Epoch: 3/15.. Loss: 0.4557.. Test accuracy: 46.9375.. 0.0991 s/batch
# Epoch: 3/15.. Loss: 0.4998.. Test accuracy: 46.5625.. 0.0994 s/batch
# Epoch: 3/15.. Loss: 0.4540.. Test accuracy: 45.8125.. 0.0925 s/batch
# Epoch: 4/15.. Loss: 0.5160.. Test accuracy: 48.1250.. 0.0175 s/batch
# Epoch: 4/15.. Loss: 0.3834.. Test accuracy: 47.4375.. 0.1146 s/batch
# Epoch: 4/15.. Loss: 0.3701.. Test accuracy: 47.1875.. 0.0951 s/batch
# Epoch: 4/15.. Loss: 0.3775.. Test accuracy: 46.8750.. 0.0933 s/batch
# Epoch: 4/15.. Loss: 0.3233.. Test accuracy: 47.0625.. 0.0954 s/batch
# Epoch: 4/15.. Loss: 0.3491.. Test accuracy: 44.1250.. 0.1031 s/batch
# Epoch: 4/15.. Loss: 0.3677.. Test accuracy: 45.8125.. 0.1022 s/batch
# Epoch: 4/15.. Loss: 0.3831.. Test accuracy: 46.9375.. 0.0938 s/batch
# Epoch: 4/15.. Loss: 0.3975.. Test accuracy: 47.3125.. 0.0942 s/batch
# Epoch: 4/15.. Loss: 0.3702.. Test accuracy: 47.6875.. 0.0930 s/batch
# Epoch: 4/15.. Loss: 0.3488.. Test accuracy: 47.1875.. 0.0976 s/batch
# Epoch: 4/15.. Loss: 0.3434.. Test accuracy: 48.0000.. 0.0964 s/batch
# Epoch: 4/15.. Loss: 0.4139.. Test accuracy: 44.5625.. 0.0931 s/batch
# Epoch: 4/15.. Loss: 0.4027.. Test accuracy: 45.6250.. 0.0971 s/batch
# Epoch: 4/15.. Loss: 0.3695.. Test accuracy: 46.5625.. 0.1002 s/batch
# Epoch: 4/15.. Loss: 0.3647.. Test accuracy: 46.2500.. 0.1152 s/batch
# Epoch: 4/15.. Loss: 0.3726.. Test accuracy: 47.8750.. 0.1064 s/batch
# Epoch: 4/15.. Loss: 0.3764.. Test accuracy: 45.8125.. 0.0983 s/batch
# Epoch: 4/15.. Loss: 0.3691.. Test accuracy: 45.6250.. 0.0968 s/batch
# Epoch: 4/15.. Loss: 0.4038.. Test accuracy: 46.4375.. 0.0989 s/batch
# Epoch: 4/15.. Loss: 0.3786.. Test accuracy: 47.3750.. 0.1027 s/batch
# Epoch: 4/15.. Loss: 0.4274.. Test accuracy: 46.5000.. 0.1005 s/batch
# Epoch: 4/15.. Loss: 0.4230.. Test accuracy: 46.7500.. 0.0974 s/batch
# Epoch: 4/15.. Loss: 0.4211.. Test accuracy: 47.1250.. 0.0937 s/batch
# Epoch: 4/15.. Loss: 0.3994.. Test accuracy: 46.5625.. 0.1002 s/batch
# Epoch: 4/15.. Loss: 0.4094.. Test accuracy: 45.2500.. 0.0958 s/batch
# Epoch: 4/15.. Loss: 0.3766.. Test accuracy: 45.5625.. 0.0982 s/batch
# Epoch: 4/15.. Loss: 0.3980.. Test accuracy: 45.5000.. 0.0961 s/batch
# Epoch: 4/15.. Loss: 0.4352.. Test accuracy: 45.8125.. 0.1086 s/batch
# Epoch: 4/15.. Loss: 0.4272.. Test accuracy: 46.2500.. 0.0958 s/batch
# Epoch: 4/15.. Loss: 0.4034.. Test accuracy: 45.6250.. 0.0938 s/batch
# Epoch: 4/15.. Loss: 0.4144.. Test accuracy: 45.3125.. 0.1000 s/batch
# Epoch: 4/15.. Loss: 0.3594.. Test accuracy: 47.1875.. 0.0930 s/batch
# Epoch: 4/15.. Loss: 0.4172.. Test accuracy: 45.9375.. 0.0965 s/batch
# Epoch: 4/15.. Loss: 0.4026.. Test accuracy: 46.8125.. 0.0925 s/batch
# Epoch: 4/15.. Loss: 0.3875.. Test accuracy: 46.9375.. 0.1055 s/batch
# Epoch: 4/15.. Loss: 0.4338.. Test accuracy: 45.4375.. 0.0977 s/batch
# Epoch: 4/15.. Loss: 0.4085.. Test accuracy: 46.8125.. 0.1042 s/batch
# Epoch: 4/15.. Loss: 0.4078.. Test accuracy: 46.0000.. 0.0902 s/batch
# Epoch: 5/15.. Loss: 0.3010.. Test accuracy: 46.6250.. 0.0834 s/batch
# Epoch: 5/15.. Loss: 0.2531.. Test accuracy: 46.8125.. 0.0946 s/batch
# Epoch: 5/15.. Loss: 0.2099.. Test accuracy: 47.6875.. 0.1025 s/batch
# Epoch: 5/15.. Loss: 0.2250.. Test accuracy: 46.1875.. 0.0923 s/batch
# Epoch: 5/15.. Loss: 0.2692.. Test accuracy: 46.9375.. 0.0940 s/batch
# Epoch: 5/15.. Loss: 0.2471.. Test accuracy: 47.8125.. 0.0914 s/batch
# Epoch: 5/15.. Loss: 0.2502.. Test accuracy: 46.8125.. 0.0929 s/batch
# Epoch: 5/15.. Loss: 0.2834.. Test accuracy: 47.0625.. 0.1036 s/batch
# Epoch: 5/15.. Loss: 0.2865.. Test accuracy: 46.8750.. 0.0953 s/batch
# Epoch: 5/15.. Loss: 0.2692.. Test accuracy: 46.0625.. 0.0976 s/batch
# Epoch: 5/15.. Loss: 0.2741.. Test accuracy: 47.3125.. 0.0975 s/batch
# Epoch: 5/15.. Loss: 0.2539.. Test accuracy: 46.5625.. 0.1009 s/batch
# Epoch: 5/15.. Loss: 0.3013.. Test accuracy: 46.6250.. 0.0971 s/batch
# Epoch: 5/15.. Loss: 0.2434.. Test accuracy: 48.3750.. 0.0949 s/batch
# Epoch: 5/15.. Loss: 0.2735.. Test accuracy: 47.2500.. 0.1040 s/batch
# Epoch: 5/15.. Loss: 0.2951.. Test accuracy: 47.6875.. 0.0907 s/batch
# Epoch: 5/15.. Loss: 0.2999.. Test accuracy: 46.1250.. 0.0914 s/batch
# Epoch: 5/15.. Loss: 0.2629.. Test accuracy: 46.4375.. 0.1111 s/batch
# Epoch: 5/15.. Loss: 0.3106.. Test accuracy: 46.8125.. 0.0933 s/batch
# Epoch: 5/15.. Loss: 0.3137.. Test accuracy: 47.5625.. 0.0908 s/batch
# Epoch: 5/15.. Loss: 0.3358.. Test accuracy: 48.1250.. 0.0921 s/batch
# Epoch: 5/15.. Loss: 0.3198.. Test accuracy: 46.8750.. 0.0971 s/batch
# Epoch: 5/15.. Loss: 0.2908.. Test accuracy: 46.7500.. 0.0991 s/batch
# Epoch: 5/15.. Loss: 0.2864.. Test accuracy: 47.3125.. 0.0944 s/batch
# Epoch: 5/15.. Loss: 0.2857.. Test accuracy: 48.0625.. 0.0936 s/batch
# Epoch: 5/15.. Loss: 0.3130.. Test accuracy: 47.3750.. 0.0980 s/batch
# Epoch: 5/15.. Loss: 0.2971.. Test accuracy: 47.3125.. 0.0929 s/batch
# Epoch: 5/15.. Loss: 0.3221.. Test accuracy: 46.3750.. 0.0938 s/batch
# Epoch: 5/15.. Loss: 0.2963.. Test accuracy: 47.0000.. 0.0966 s/batch
# Epoch: 5/15.. Loss: 0.3026.. Test accuracy: 47.1250.. 0.0981 s/batch
# Epoch: 5/15.. Loss: 0.3422.. Test accuracy: 46.6250.. 0.0962 s/batch
# Epoch: 5/15.. Loss: 0.3096.. Test accuracy: 46.0000.. 0.0941 s/batch
# Epoch: 5/15.. Loss: 0.2943.. Test accuracy: 47.0625.. 0.0929 s/batch
# Epoch: 5/15.. Loss: 0.3057.. Test accuracy: 46.6875.. 0.0964 s/batch
# Epoch: 5/15.. Loss: 0.3017.. Test accuracy: 48.3125.. 0.0994 s/batch
# Epoch: 5/15.. Loss: 0.3450.. Test accuracy: 45.9375.. 0.1014 s/batch
# Epoch: 5/15.. Loss: 0.3345.. Test accuracy: 46.8125.. 0.0899 s/batch
# Epoch: 5/15.. Loss: 0.3035.. Test accuracy: 46.6875.. 0.0915 s/batch
# Epoch: 6/15.. Loss: 0.2319.. Test accuracy: 48.9375.. 0.0554 s/batch
# Epoch: 6/15.. Loss: 0.1911.. Test accuracy: 48.3125.. 0.0964 s/batch
# Epoch: 6/15.. Loss: 0.1697.. Test accuracy: 48.1250.. 0.0912 s/batch
# Epoch: 6/15.. Loss: 0.1786.. Test accuracy: 47.4375.. 0.0920 s/batch
# Epoch: 6/15.. Loss: 0.1709.. Test accuracy: 49.2500.. 0.0927 s/batch
# Epoch: 6/15.. Loss: 0.1757.. Test accuracy: 48.3750.. 0.0939 s/batch
# Epoch: 6/15.. Loss: 0.1760.. Test accuracy: 46.4375.. 0.1002 s/batch
# Epoch: 6/15.. Loss: 0.1935.. Test accuracy: 46.9375.. 0.0927 s/batch
# Epoch: 6/15.. Loss: 0.1644.. Test accuracy: 46.8125.. 0.0908 s/batch
# Epoch: 6/15.. Loss: 0.2037.. Test accuracy: 47.0000.. 0.0941 s/batch
# Epoch: 6/15.. Loss: 0.1784.. Test accuracy: 48.7500.. 0.0949 s/batch
# Epoch: 6/15.. Loss: 0.2122.. Test accuracy: 47.4375.. 0.0980 s/batch
# Epoch: 6/15.. Loss: 0.2076.. Test accuracy: 47.6875.. 0.0932 s/batch
# Epoch: 6/15.. Loss: 0.2005.. Test accuracy: 46.6875.. 0.0914 s/batch
# Epoch: 6/15.. Loss: 0.2045.. Test accuracy: 47.5000.. 0.0923 s/batch
# Epoch: 6/15.. Loss: 0.1886.. Test accuracy: 47.5625.. 0.0938 s/batch
# Epoch: 6/15.. Loss: 0.2066.. Test accuracy: 46.0000.. 0.0974 s/batch
# Epoch: 6/15.. Loss: 0.2172.. Test accuracy: 45.9375.. 0.1046 s/batch
# Epoch: 6/15.. Loss: 0.2335.. Test accuracy: 47.2500.. 0.1038 s/batch
# Epoch: 6/15.. Loss: 0.1990.. Test accuracy: 47.8750.. 0.1022 s/batch
# Epoch: 6/15.. Loss: 0.2320.. Test accuracy: 46.5625.. 0.1023 s/batch
# Epoch: 6/15.. Loss: 0.2223.. Test accuracy: 46.1875.. 0.0942 s/batch
# Epoch: 6/15.. Loss: 0.1987.. Test accuracy: 47.1875.. 0.1912 s/batch
# Epoch: 6/15.. Loss: 0.2177.. Test accuracy: 47.4375.. 0.1023 s/batch
# Epoch: 6/15.. Loss: 0.2206.. Test accuracy: 46.8125.. 0.0928 s/batch
# Epoch: 6/15.. Loss: 0.2205.. Test accuracy: 46.1875.. 0.0941 s/batch
# Epoch: 6/15.. Loss: 0.2520.. Test accuracy: 48.1875.. 0.0987 s/batch
# Epoch: 6/15.. Loss: 0.2528.. Test accuracy: 45.8750.. 0.0939 s/batch
# Epoch: 6/15.. Loss: 0.2441.. Test accuracy: 46.4375.. 0.0960 s/batch
# Epoch: 6/15.. Loss: 0.2231.. Test accuracy: 45.3750.. 0.0916 s/batch
# Epoch: 6/15.. Loss: 0.2714.. Test accuracy: 46.7500.. 0.0928 s/batch
# Epoch: 6/15.. Loss: 0.2713.. Test accuracy: 46.6250.. 0.0928 s/batch
# Epoch: 6/15.. Loss: 0.2630.. Test accuracy: 46.1875.. 0.0905 s/batch
# Epoch: 6/15.. Loss: 0.2803.. Test accuracy: 45.8750.. 0.0987 s/batch
# Epoch: 6/15.. Loss: 0.2458.. Test accuracy: 45.8750.. 0.0922 s/batch
# Epoch: 6/15.. Loss: 0.2312.. Test accuracy: 47.1875.. 0.0897 s/batch
# Epoch: 6/15.. Loss: 0.2547.. Test accuracy: 46.8750.. 0.0933 s/batch
# Epoch: 6/15.. Loss: 0.2157.. Test accuracy: 47.8125.. 0.0938 s/batch
# Epoch: 7/15.. Loss: 0.2423.. Test accuracy: 47.1875.. 0.0298 s/batch
# Epoch: 7/15.. Loss: 0.1322.. Test accuracy: 46.8750.. 0.0975 s/batch
# Epoch: 7/15.. Loss: 0.1207.. Test accuracy: 46.3750.. 0.0939 s/batch
# Epoch: 7/15.. Loss: 0.0977.. Test accuracy: 48.4375.. 0.1279 s/batch
# Epoch: 7/15.. Loss: 0.1144.. Test accuracy: 47.8125.. 0.0953 s/batch
# Epoch: 7/15.. Loss: 0.1095.. Test accuracy: 49.1250.. 0.0959 s/batch
# Epoch: 7/15.. Loss: 0.1226.. Test accuracy: 47.3125.. 0.0932 s/batch
# Epoch: 7/15.. Loss: 0.1110.. Test accuracy: 47.8750.. 0.0941 s/batch
# Epoch: 7/15.. Loss: 0.1064.. Test accuracy: 47.3125.. 0.0894 s/batch
# Epoch: 7/15.. Loss: 0.1311.. Test accuracy: 46.3750.. 0.0914 s/batch
# Epoch: 7/15.. Loss: 0.1139.. Test accuracy: 47.1875.. 0.1039 s/batch
# Epoch: 7/15.. Loss: 0.1480.. Test accuracy: 47.1875.. 0.0923 s/batch
# Epoch: 7/15.. Loss: 0.1767.. Test accuracy: 46.8125.. 0.0917 s/batch
# Epoch: 7/15.. Loss: 0.1771.. Test accuracy: 47.3125.. 0.0922 s/batch
# Epoch: 7/15.. Loss: 0.1592.. Test accuracy: 47.6250.. 0.0914 s/batch
# Epoch: 7/15.. Loss: 0.1554.. Test accuracy: 46.1250.. 0.0971 s/batch
# Epoch: 7/15.. Loss: 0.1577.. Test accuracy: 45.8125.. 0.0999 s/batch
# Epoch: 7/15.. Loss: 0.1449.. Test accuracy: 46.1875.. 0.0925 s/batch
# Epoch: 7/15.. Loss: 0.1859.. Test accuracy: 46.9375.. 0.0921 s/batch
# Epoch: 7/15.. Loss: 0.1643.. Test accuracy: 45.9375.. 0.0922 s/batch
# Epoch: 7/15.. Loss: 0.1622.. Test accuracy: 47.6250.. 0.0981 s/batch
# Epoch: 7/15.. Loss: 0.1806.. Test accuracy: 46.1875.. 0.0932 s/batch
# Epoch: 7/15.. Loss: 0.1724.. Test accuracy: 46.5625.. 0.0937 s/batch
# Epoch: 7/15.. Loss: 0.1719.. Test accuracy: 46.8125.. 0.1060 s/batch
# Epoch: 7/15.. Loss: 0.1360.. Test accuracy: 45.9375.. 0.0920 s/batch
# Epoch: 7/15.. Loss: 0.1966.. Test accuracy: 44.5625.. 0.0997 s/batch
# Epoch: 7/15.. Loss: 0.1861.. Test accuracy: 46.6875.. 0.0910 s/batch
# Epoch: 7/15.. Loss: 0.1743.. Test accuracy: 46.3750.. 0.0913 s/batch
# Epoch: 7/15.. Loss: 0.2184.. Test accuracy: 46.5625.. 0.0901 s/batch
# Epoch: 7/15.. Loss: 0.1475.. Test accuracy: 46.3125.. 0.0942 s/batch
# Epoch: 7/15.. Loss: 0.2232.. Test accuracy: 45.8125.. 0.1009 s/batch
# Epoch: 7/15.. Loss: 0.1603.. Test accuracy: 47.6250.. 0.0945 s/batch
# Epoch: 7/15.. Loss: 0.1956.. Test accuracy: 47.1250.. 0.0915 s/batch
# Epoch: 7/15.. Loss: 0.1901.. Test accuracy: 45.8750.. 0.1015 s/batch
# Epoch: 7/15.. Loss: 0.2146.. Test accuracy: 47.0625.. 0.0940 s/batch
# Epoch: 7/15.. Loss: 0.1810.. Test accuracy: 48.2500.. 0.0927 s/batch
# Epoch: 7/15.. Loss: 0.1801.. Test accuracy: 47.9375.. 0.0992 s/batch
# Epoch: 7/15.. Loss: 0.1463.. Test accuracy: 46.8125.. 0.0912 s/batch
# Epoch: 7/15.. Loss: 0.2107.. Test accuracy: 46.8750.. 0.0889 s/batch
# Epoch: 8/15.. Loss: 0.1097.. Test accuracy: 47.3750.. 0.0920 s/batch
# Epoch: 8/15.. Loss: 0.0977.. Test accuracy: 47.1250.. 0.0937 s/batch
# Epoch: 8/15.. Loss: 0.0916.. Test accuracy: 46.9375.. 0.1002 s/batch
# Epoch: 8/15.. Loss: 0.0915.. Test accuracy: 47.8125.. 0.0983 s/batch
# Epoch: 8/15.. Loss: 0.1050.. Test accuracy: 47.5000.. 0.0903 s/batch
# Epoch: 8/15.. Loss: 0.1034.. Test accuracy: 47.8125.. 0.1068 s/batch
# Epoch: 8/15.. Loss: 0.0826.. Test accuracy: 48.1250.. 0.0929 s/batch
# Epoch: 8/15.. Loss: 0.0953.. Test accuracy: 48.6875.. 0.0983 s/batch
# Epoch: 8/15.. Loss: 0.0853.. Test accuracy: 46.8750.. 0.0923 s/batch
# Epoch: 8/15.. Loss: 0.0834.. Test accuracy: 48.0625.. 0.0964 s/batch
# Epoch: 8/15.. Loss: 0.0867.. Test accuracy: 47.1250.. 0.0920 s/batch
# Epoch: 8/15.. Loss: 0.1104.. Test accuracy: 47.0625.. 0.0991 s/batch
# Epoch: 8/15.. Loss: 0.1152.. Test accuracy: 47.4375.. 0.0940 s/batch
# Epoch: 8/15.. Loss: 0.1042.. Test accuracy: 47.0625.. 0.0928 s/batch
# Epoch: 8/15.. Loss: 0.0917.. Test accuracy: 46.5625.. 0.0911 s/batch
# Epoch: 8/15.. Loss: 0.1064.. Test accuracy: 46.3750.. 0.0941 s/batch
# Epoch: 8/15.. Loss: 0.0988.. Test accuracy: 46.3750.. 0.0934 s/batch
# Epoch: 8/15.. Loss: 0.1188.. Test accuracy: 47.3750.. 0.0926 s/batch
# Epoch: 8/15.. Loss: 0.1084.. Test accuracy: 46.7500.. 0.0922 s/batch
# Epoch: 8/15.. Loss: 0.1538.. Test accuracy: 46.5625.. 0.0959 s/batch
# Epoch: 8/15.. Loss: 0.1584.. Test accuracy: 46.8125.. 0.0922 s/batch
# Epoch: 8/15.. Loss: 0.1496.. Test accuracy: 46.1875.. 0.1017 s/batch
# Epoch: 8/15.. Loss: 0.1412.. Test accuracy: 45.3750.. 0.0937 s/batch
# Epoch: 8/15.. Loss: 0.1453.. Test accuracy: 46.2500.. 0.0917 s/batch
# Epoch: 8/15.. Loss: 0.1347.. Test accuracy: 45.5625.. 0.1013 s/batch
# Epoch: 8/15.. Loss: 0.1553.. Test accuracy: 47.6875.. 0.0950 s/batch
# Epoch: 8/15.. Loss: 0.1575.. Test accuracy: 46.8125.. 0.1019 s/batch
# Epoch: 8/15.. Loss: 0.1488.. Test accuracy: 47.9375.. 0.0909 s/batch
# Epoch: 8/15.. Loss: 0.1388.. Test accuracy: 46.6875.. 0.0922 s/batch
# Epoch: 8/15.. Loss: 0.1448.. Test accuracy: 47.6250.. 0.0986 s/batch
# Epoch: 8/15.. Loss: 0.1430.. Test accuracy: 47.8750.. 0.0960 s/batch
# Epoch: 8/15.. Loss: 0.1550.. Test accuracy: 47.7500.. 0.0915 s/batch
# Epoch: 8/15.. Loss: 0.1648.. Test accuracy: 46.8750.. 0.0956 s/batch
# Epoch: 8/15.. Loss: 0.2007.. Test accuracy: 45.6875.. 0.0929 s/batch
# Epoch: 8/15.. Loss: 0.1793.. Test accuracy: 46.1250.. 0.0961 s/batch
# Epoch: 8/15.. Loss: 0.2259.. Test accuracy: 45.8750.. 0.0932 s/batch
# Epoch: 8/15.. Loss: 0.1599.. Test accuracy: 46.0000.. 0.0914 s/batch
# Epoch: 8/15.. Loss: 0.1697.. Test accuracy: 46.1250.. 0.0933 s/batch
# Epoch: 9/15.. Loss: 0.1298.. Test accuracy: 48.3125.. 0.0641 s/batch
# Epoch: 9/15.. Loss: 0.0656.. Test accuracy: 47.3125.. 0.0969 s/batch
# Epoch: 9/15.. Loss: 0.0816.. Test accuracy: 45.6250.. 0.0915 s/batch
# Epoch: 9/15.. Loss: 0.0702.. Test accuracy: 46.5000.. 0.0918 s/batch
# Epoch: 9/15.. Loss: 0.0809.. Test accuracy: 47.6875.. 0.0916 s/batch
# Epoch: 9/15.. Loss: 0.0877.. Test accuracy: 46.0000.. 0.0935 s/batch
# Epoch: 9/15.. Loss: 0.0649.. Test accuracy: 46.8750.. 0.0959 s/batch
# Epoch: 9/15.. Loss: 0.0920.. Test accuracy: 47.1250.. 0.0906 s/batch
# Epoch: 9/15.. Loss: 0.0822.. Test accuracy: 46.8750.. 0.0995 s/batch
# Epoch: 9/15.. Loss: 0.1141.. Test accuracy: 46.4375.. 0.1021 s/batch
# Epoch: 9/15.. Loss: 0.0743.. Test accuracy: 47.1875.. 0.0922 s/batch
# Epoch: 9/15.. Loss: 0.0876.. Test accuracy: 47.7500.. 0.0969 s/batch
# Epoch: 9/15.. Loss: 0.0785.. Test accuracy: 47.3125.. 0.0978 s/batch
# Epoch: 9/15.. Loss: 0.1060.. Test accuracy: 46.4375.. 0.0961 s/batch
# Epoch: 9/15.. Loss: 0.1032.. Test accuracy: 48.5000.. 0.0914 s/batch
# Epoch: 9/15.. Loss: 0.0954.. Test accuracy: 46.9375.. 0.0932 s/batch
# Epoch: 9/15.. Loss: 0.1049.. Test accuracy: 45.8750.. 0.0978 s/batch
# Epoch: 9/15.. Loss: 0.1038.. Test accuracy: 46.5000.. 0.0914 s/batch
# Epoch: 9/15.. Loss: 0.0942.. Test accuracy: 47.3750.. 0.0996 s/batch
# Epoch: 9/15.. Loss: 0.1074.. Test accuracy: 47.1250.. 0.0905 s/batch
# Epoch: 9/15.. Loss: 0.1040.. Test accuracy: 47.3125.. 0.0920 s/batch
# Epoch: 9/15.. Loss: 0.1201.. Test accuracy: 47.5625.. 0.0994 s/batch
# Epoch: 9/15.. Loss: 0.1094.. Test accuracy: 47.6875.. 0.0901 s/batch
# Epoch: 9/15.. Loss: 0.1241.. Test accuracy: 46.8750.. 0.0936 s/batch
# Epoch: 9/15.. Loss: 0.1497.. Test accuracy: 47.0625.. 0.0906 s/batch
# Epoch: 9/15.. Loss: 0.1256.. Test accuracy: 46.6250.. 0.0924 s/batch
# Epoch: 9/15.. Loss: 0.1224.. Test accuracy: 47.5625.. 0.0984 s/batch
# Epoch: 9/15.. Loss: 0.1208.. Test accuracy: 48.0625.. 0.0917 s/batch
# Epoch: 9/15.. Loss: 0.1320.. Test accuracy: 46.6875.. 0.0984 s/batch
# Epoch: 9/15.. Loss: 0.1363.. Test accuracy: 47.2500.. 0.0973 s/batch
# Epoch: 9/15.. Loss: 0.1101.. Test accuracy: 47.6250.. 0.1055 s/batch
# Epoch: 9/15.. Loss: 0.1104.. Test accuracy: 47.2500.. 0.0969 s/batch
# Epoch: 9/15.. Loss: 0.1069.. Test accuracy: 47.0625.. 0.0901 s/batch
# Epoch: 9/15.. Loss: 0.1092.. Test accuracy: 47.7500.. 0.0912 s/batch
# Epoch: 9/15.. Loss: 0.0884.. Test accuracy: 47.8750.. 0.0902 s/batch
# Epoch: 9/15.. Loss: 0.1386.. Test accuracy: 46.8125.. 0.0903 s/batch
# Epoch: 9/15.. Loss: 0.1454.. Test accuracy: 46.6875.. 0.0979 s/batch
# Epoch: 9/15.. Loss: 0.1202.. Test accuracy: 47.3125.. 0.0981 s/batch
# Epoch: 10/15.. Loss: 0.1240.. Test accuracy: 46.3125.. 0.0371 s/batch
# Epoch: 10/15.. Loss: 0.0783.. Test accuracy: 47.7500.. 0.0971 s/batch
# Epoch: 10/15.. Loss: 0.0794.. Test accuracy: 47.3750.. 0.0907 s/batch
# Epoch: 10/15.. Loss: 0.0677.. Test accuracy: 46.9375.. 0.0960 s/batch
# Epoch: 10/15.. Loss: 0.0712.. Test accuracy: 47.2500.. 0.0918 s/batch
# Epoch: 10/15.. Loss: 0.0669.. Test accuracy: 48.6875.. 0.0916 s/batch
# Epoch: 10/15.. Loss: 0.0771.. Test accuracy: 47.3750.. 0.0994 s/batch
# Epoch: 10/15.. Loss: 0.0793.. Test accuracy: 46.0625.. 0.0950 s/batch
# Epoch: 10/15.. Loss: 0.0780.. Test accuracy: 45.6875.. 0.0967 s/batch
# Epoch: 10/15.. Loss: 0.0740.. Test accuracy: 46.2500.. 0.0928 s/batch
# Epoch: 10/15.. Loss: 0.0636.. Test accuracy: 48.0000.. 0.0921 s/batch
# Epoch: 10/15.. Loss: 0.0584.. Test accuracy: 47.2500.. 0.0914 s/batch
# Epoch: 10/15.. Loss: 0.0609.. Test accuracy: 47.3750.. 0.0912 s/batch
# Epoch: 10/15.. Loss: 0.0658.. Test accuracy: 47.3750.. 0.1118 s/batch
# Epoch: 10/15.. Loss: 0.0824.. Test accuracy: 47.5000.. 0.0997 s/batch
# Epoch: 10/15.. Loss: 0.0637.. Test accuracy: 47.6250.. 0.0917 s/batch
# Epoch: 10/15.. Loss: 0.0705.. Test accuracy: 46.4375.. 0.0950 s/batch
# Epoch: 10/15.. Loss: 0.1068.. Test accuracy: 46.8125.. 0.0914 s/batch
# Epoch: 10/15.. Loss: 0.0784.. Test accuracy: 48.0000.. 0.0968 s/batch
# Epoch: 10/15.. Loss: 0.0731.. Test accuracy: 46.0625.. 0.0949 s/batch
# Epoch: 10/15.. Loss: 0.0747.. Test accuracy: 47.0625.. 0.0923 s/batch
# Epoch: 10/15.. Loss: 0.0996.. Test accuracy: 45.3750.. 0.0926 s/batch
# Epoch: 10/15.. Loss: 0.1144.. Test accuracy: 46.9375.. 0.0966 s/batch
# Epoch: 10/15.. Loss: 0.1139.. Test accuracy: 48.1250.. 0.0964 s/batch
# Epoch: 10/15.. Loss: 0.1071.. Test accuracy: 46.2500.. 0.0912 s/batch
# Epoch: 10/15.. Loss: 0.0893.. Test accuracy: 46.7500.. 0.0928 s/batch
# Epoch: 10/15.. Loss: 0.0912.. Test accuracy: 48.8125.. 0.0916 s/batch
# Epoch: 10/15.. Loss: 0.0908.. Test accuracy: 47.0625.. 0.0922 s/batch
# Epoch: 10/15.. Loss: 0.0792.. Test accuracy: 46.0625.. 0.0952 s/batch
# Epoch: 10/15.. Loss: 0.1001.. Test accuracy: 46.6250.. 0.0917 s/batch
# Epoch: 10/15.. Loss: 0.1083.. Test accuracy: 48.0625.. 0.0913 s/batch
# Epoch: 10/15.. Loss: 0.1335.. Test accuracy: 46.3750.. 0.0925 s/batch
# Epoch: 10/15.. Loss: 0.1393.. Test accuracy: 44.6250.. 0.0919 s/batch
# Epoch: 10/15.. Loss: 0.1504.. Test accuracy: 45.8125.. 0.0965 s/batch
# Epoch: 10/15.. Loss: 0.1395.. Test accuracy: 48.1875.. 0.1025 s/batch
# Epoch: 10/15.. Loss: 0.1308.. Test accuracy: 48.0625.. 0.0930 s/batch
# Epoch: 10/15.. Loss: 0.1162.. Test accuracy: 47.0000.. 0.0910 s/batch
# Epoch: 10/15.. Loss: 0.1241.. Test accuracy: 46.8125.. 0.0916 s/batch
# Epoch: 10/15.. Loss: 0.1366.. Test accuracy: 47.7500.. 0.0933 s/batch
# Epoch: 11/15.. Loss: 0.0671.. Test accuracy: 46.3750.. 0.1045 s/batch
# Epoch: 11/15.. Loss: 0.1074.. Test accuracy: 48.0000.. 0.0939 s/batch
# Epoch: 11/15.. Loss: 0.0646.. Test accuracy: 47.0625.. 0.0936 s/batch
# Epoch: 11/15.. Loss: 0.0881.. Test accuracy: 48.0625.. 0.1057 s/batch
# Epoch: 11/15.. Loss: 0.0713.. Test accuracy: 46.3750.. 0.0895 s/batch
# Epoch: 11/15.. Loss: 0.0623.. Test accuracy: 47.6875.. 0.0998 s/batch
# Epoch: 11/15.. Loss: 0.0602.. Test accuracy: 47.5625.. 0.0971 s/batch
# Epoch: 11/15.. Loss: 0.0587.. Test accuracy: 47.8750.. 0.0970 s/batch
# Epoch: 11/15.. Loss: 0.0536.. Test accuracy: 47.4375.. 0.0935 s/batch
# Epoch: 11/15.. Loss: 0.0729.. Test accuracy: 46.5625.. 0.0923 s/batch
# Epoch: 11/15.. Loss: 0.0933.. Test accuracy: 47.0625.. 0.0998 s/batch
# Epoch: 11/15.. Loss: 0.0726.. Test accuracy: 47.8750.. 0.0887 s/batch
# Epoch: 11/15.. Loss: 0.0657.. Test accuracy: 47.3125.. 0.0914 s/batch
# Epoch: 11/15.. Loss: 0.0901.. Test accuracy: 46.1250.. 0.0914 s/batch
# Epoch: 11/15.. Loss: 0.0556.. Test accuracy: 46.5000.. 0.0931 s/batch
# Epoch: 11/15.. Loss: 0.0775.. Test accuracy: 46.6875.. 0.0971 s/batch
# Epoch: 11/15.. Loss: 0.0975.. Test accuracy: 47.6875.. 0.1067 s/batch
# Epoch: 11/15.. Loss: 0.0791.. Test accuracy: 47.6250.. 0.0920 s/batch
# Epoch: 11/15.. Loss: 0.0695.. Test accuracy: 46.1875.. 0.0942 s/batch
# Epoch: 11/15.. Loss: 0.0626.. Test accuracy: 47.1875.. 0.0927 s/batch
# Epoch: 11/15.. Loss: 0.0837.. Test accuracy: 46.7500.. 0.1163 s/batch
# Epoch: 11/15.. Loss: 0.0774.. Test accuracy: 47.1875.. 0.0906 s/batch
# Epoch: 11/15.. Loss: 0.0770.. Test accuracy: 45.6250.. 0.0929 s/batch
# Epoch: 11/15.. Loss: 0.0951.. Test accuracy: 47.5625.. 0.1014 s/batch
# Epoch: 11/15.. Loss: 0.0855.. Test accuracy: 46.9375.. 0.1201 s/batch
# Epoch: 11/15.. Loss: 0.1067.. Test accuracy: 46.8750.. 0.1310 s/batch
# Epoch: 11/15.. Loss: 0.1054.. Test accuracy: 45.8125.. 0.1376 s/batch
# Epoch: 11/15.. Loss: 0.0961.. Test accuracy: 46.7500.. 0.1765 s/batch
# Epoch: 11/15.. Loss: 0.1115.. Test accuracy: 47.1250.. 0.4513 s/batch
# Epoch: 11/15.. Loss: 0.1082.. Test accuracy: 47.1875.. 0.2576 s/batch
# Epoch: 11/15.. Loss: 0.1112.. Test accuracy: 46.0625.. 0.3643 s/batch
# Epoch: 11/15.. Loss: 0.1131.. Test accuracy: 46.4375.. 0.2530 s/batch
# Epoch: 11/15.. Loss: 0.0908.. Test accuracy: 47.3125.. 0.2457 s/batch
# Epoch: 11/15.. Loss: 0.1079.. Test accuracy: 47.1875.. 0.2941 s/batch
# Epoch: 11/15.. Loss: 0.0911.. Test accuracy: 46.3750.. 0.2677 s/batch
# Epoch: 11/15.. Loss: 0.1029.. Test accuracy: 46.5000.. 0.2502 s/batch
# Epoch: 11/15.. Loss: 0.0936.. Test accuracy: 46.9375.. 0.2648 s/batch
# Epoch: 11/15.. Loss: 0.0807.. Test accuracy: 48.0000.. 0.2658 s/batch
# Epoch: 12/15.. Loss: 0.0811.. Test accuracy: 47.9375.. 0.1926 s/batch
# Epoch: 12/15.. Loss: 0.0567.. Test accuracy: 47.5000.. 0.2347 s/batch
# Epoch: 12/15.. Loss: 0.0570.. Test accuracy: 47.0625.. 0.2326 s/batch
# Epoch: 12/15.. Loss: 0.0524.. Test accuracy: 47.0000.. 0.2589 s/batch
# Epoch: 12/15.. Loss: 0.0563.. Test accuracy: 47.8125.. 0.2715 s/batch
# Epoch: 12/15.. Loss: 0.0751.. Test accuracy: 47.5625.. 0.2605 s/batch
# Epoch: 12/15.. Loss: 0.0511.. Test accuracy: 47.0625.. 0.2594 s/batch
# Epoch: 12/15.. Loss: 0.0673.. Test accuracy: 47.0625.. 0.3988 s/batch
# Epoch: 12/15.. Loss: 0.0589.. Test accuracy: 46.8125.. 0.2783 s/batch
# Epoch: 12/15.. Loss: 0.0706.. Test accuracy: 46.5000.. 0.2597 s/batch
# Epoch: 12/15.. Loss: 0.0815.. Test accuracy: 46.3750.. 0.2722 s/batch
# Epoch: 12/15.. Loss: 0.0659.. Test accuracy: 48.7500.. 0.2607 s/batch
# Epoch: 12/15.. Loss: 0.0602.. Test accuracy: 48.2500.. 0.2827 s/batch
# Epoch: 12/15.. Loss: 0.0786.. Test accuracy: 46.9375.. 0.2554 s/batch
# Epoch: 12/15.. Loss: 0.0804.. Test accuracy: 46.3750.. 0.3238 s/batch
# Epoch: 12/15.. Loss: 0.0612.. Test accuracy: 47.6875.. 0.2683 s/batch
# Epoch: 12/15.. Loss: 0.0847.. Test accuracy: 46.8750.. 0.2527 s/batch
# Epoch: 12/15.. Loss: 0.0751.. Test accuracy: 46.8125.. 0.3041 s/batch
# Epoch: 12/15.. Loss: 0.0571.. Test accuracy: 46.3750.. 0.3086 s/batch
# Epoch: 12/15.. Loss: 0.0623.. Test accuracy: 47.6875.. 0.2538 s/batch
# Epoch: 12/15.. Loss: 0.0629.. Test accuracy: 47.1875.. 0.2674 s/batch
# Epoch: 12/15.. Loss: 0.0824.. Test accuracy: 48.0625.. 0.2588 s/batch
# Epoch: 12/15.. Loss: 0.0709.. Test accuracy: 46.5000.. 0.2504 s/batch
# Epoch: 12/15.. Loss: 0.0611.. Test accuracy: 46.8750.. 0.2719 s/batch
# Epoch: 12/15.. Loss: 0.0971.. Test accuracy: 46.9375.. 0.2862 s/batch
# Epoch: 12/15.. Loss: 0.0790.. Test accuracy: 46.5625.. 0.2478 s/batch
# Epoch: 12/15.. Loss: 0.0964.. Test accuracy: 47.5000.. 0.2493 s/batch
# Epoch: 12/15.. Loss: 0.0776.. Test accuracy: 46.1250.. 0.2725 s/batch
# Epoch: 12/15.. Loss: 0.0851.. Test accuracy: 46.3125.. 0.2426 s/batch
# Epoch: 12/15.. Loss: 0.0876.. Test accuracy: 46.5000.. 0.3186 s/batch
# Epoch: 12/15.. Loss: 0.0776.. Test accuracy: 47.7500.. 0.2420 s/batch
# Epoch: 12/15.. Loss: 0.0895.. Test accuracy: 46.7500.. 0.2386 s/batch
# Epoch: 12/15.. Loss: 0.0682.. Test accuracy: 45.6875.. 0.2596 s/batch
# Epoch: 12/15.. Loss: 0.0818.. Test accuracy: 47.3125.. 0.2738 s/batch
# Epoch: 12/15.. Loss: 0.0900.. Test accuracy: 46.5625.. 0.2611 s/batch
# Epoch: 12/15.. Loss: 0.0810.. Test accuracy: 45.3125.. 0.2424 s/batch
# Epoch: 12/15.. Loss: 0.0770.. Test accuracy: 46.1250.. 0.2738 s/batch
# Epoch: 12/15.. Loss: 0.1057.. Test accuracy: 48.1250.. 0.2798 s/batch
# Epoch: 13/15.. Loss: 0.0603.. Test accuracy: 46.7500.. 0.1114 s/batch
# Epoch: 13/15.. Loss: 0.0612.. Test accuracy: 47.0625.. 0.3065 s/batch
# Epoch: 13/15.. Loss: 0.0491.. Test accuracy: 46.7500.. 0.2494 s/batch
# Epoch: 13/15.. Loss: 0.0426.. Test accuracy: 45.9375.. 0.2414 s/batch
# Epoch: 13/15.. Loss: 0.0734.. Test accuracy: 46.6875.. 0.3233 s/batch
# Epoch: 13/15.. Loss: 0.0608.. Test accuracy: 46.6250.. 0.3023 s/batch
# Epoch: 13/15.. Loss: 0.0627.. Test accuracy: 46.3125.. 0.4120 s/batch
# Epoch: 13/15.. Loss: 0.0571.. Test accuracy: 44.7500.. 0.2684 s/batch
# Epoch: 13/15.. Loss: 0.0609.. Test accuracy: 46.6250.. 0.3204 s/batch
# Epoch: 13/15.. Loss: 0.0503.. Test accuracy: 47.8750.. 0.2493 s/batch
# Epoch: 13/15.. Loss: 0.0460.. Test accuracy: 47.4375.. 0.2510 s/batch
# Epoch: 13/15.. Loss: 0.0437.. Test accuracy: 47.3750.. 0.2689 s/batch
# Epoch: 13/15.. Loss: 0.0442.. Test accuracy: 46.9375.. 0.1333 s/batch
# Epoch: 13/15.. Loss: 0.0530.. Test accuracy: 46.8125.. 0.0924 s/batch
# Epoch: 13/15.. Loss: 0.0519.. Test accuracy: 46.9375.. 0.0981 s/batch
# Epoch: 13/15.. Loss: 0.0517.. Test accuracy: 46.1875.. 0.0944 s/batch
# Epoch: 13/15.. Loss: 0.0653.. Test accuracy: 47.8750.. 0.0921 s/batch
# Epoch: 13/15.. Loss: 0.0955.. Test accuracy: 46.6250.. 0.0963 s/batch
# Epoch: 13/15.. Loss: 0.0617.. Test accuracy: 44.9375.. 0.0931 s/batch
# Epoch: 13/15.. Loss: 0.0895.. Test accuracy: 47.1250.. 0.0925 s/batch
# Epoch: 13/15.. Loss: 0.0795.. Test accuracy: 47.1875.. 0.0940 s/batch
# Epoch: 13/15.. Loss: 0.0776.. Test accuracy: 46.3125.. 0.0907 s/batch
# Epoch: 13/15.. Loss: 0.0759.. Test accuracy: 46.9375.. 0.0985 s/batch
# Epoch: 13/15.. Loss: 0.0948.. Test accuracy: 47.4375.. 0.0927 s/batch
# Epoch: 13/15.. Loss: 0.0742.. Test accuracy: 47.6250.. 0.0909 s/batch
# Epoch: 13/15.. Loss: 0.0980.. Test accuracy: 46.4375.. 0.1021 s/batch
# Epoch: 13/15.. Loss: 0.0948.. Test accuracy: 46.0625.. 0.0971 s/batch
# Epoch: 13/15.. Loss: 0.0904.. Test accuracy: 46.4375.. 0.0982 s/batch
# Epoch: 13/15.. Loss: 0.1198.. Test accuracy: 48.1250.. 0.0908 s/batch
# Epoch: 13/15.. Loss: 0.0866.. Test accuracy: 46.4375.. 0.0942 s/batch
# Epoch: 13/15.. Loss: 0.1099.. Test accuracy: 46.1875.. 0.0919 s/batch
# Epoch: 13/15.. Loss: 0.1011.. Test accuracy: 45.2500.. 0.0930 s/batch
# Epoch: 13/15.. Loss: 0.0804.. Test accuracy: 46.3125.. 0.0996 s/batch
# Epoch: 13/15.. Loss: 0.1108.. Test accuracy: 45.1875.. 0.1295 s/batch
# Epoch: 13/15.. Loss: 0.0864.. Test accuracy: 45.5625.. 0.0941 s/batch
# Epoch: 13/15.. Loss: 0.1114.. Test accuracy: 47.0625.. 0.0994 s/batch
# Epoch: 13/15.. Loss: 0.1027.. Test accuracy: 46.2500.. 0.0936 s/batch
# Epoch: 13/15.. Loss: 0.1013.. Test accuracy: 46.9375.. 0.0912 s/batch
# Epoch: 14/15.. Loss: 0.0785.. Test accuracy: 46.8125.. 0.0194 s/batch
# Epoch: 14/15.. Loss: 0.0588.. Test accuracy: 46.5000.. 0.0931 s/batch
# Epoch: 14/15.. Loss: 0.0455.. Test accuracy: 47.6250.. 0.0911 s/batch
# Epoch: 14/15.. Loss: 0.0532.. Test accuracy: 47.6250.. 0.0928 s/batch
# Epoch: 14/15.. Loss: 0.0480.. Test accuracy: 47.1250.. 0.0952 s/batch
# Epoch: 14/15.. Loss: 0.0430.. Test accuracy: 47.6875.. 0.0958 s/batch
# Epoch: 14/15.. Loss: 0.0718.. Test accuracy: 46.5625.. 0.0970 s/batch
# Epoch: 14/15.. Loss: 0.0400.. Test accuracy: 46.7500.. 0.0941 s/batch
# Epoch: 14/15.. Loss: 0.0611.. Test accuracy: 46.5625.. 0.0924 s/batch
# Epoch: 14/15.. Loss: 0.0473.. Test accuracy: 47.1875.. 0.0918 s/batch
# Epoch: 14/15.. Loss: 0.0521.. Test accuracy: 47.4375.. 0.0965 s/batch
# Epoch: 14/15.. Loss: 0.0600.. Test accuracy: 48.0000.. 0.0923 s/batch
# Epoch: 14/15.. Loss: 0.0483.. Test accuracy: 47.1875.. 0.0912 s/batch
# Epoch: 14/15.. Loss: 0.0486.. Test accuracy: 47.1875.. 0.0912 s/batch
# Epoch: 14/15.. Loss: 0.0586.. Test accuracy: 46.8750.. 0.1063 s/batch
# Epoch: 14/15.. Loss: 0.0557.. Test accuracy: 47.0625.. 0.0953 s/batch
# Epoch: 14/15.. Loss: 0.0420.. Test accuracy: 46.3125.. 0.0942 s/batch
# Epoch: 14/15.. Loss: 0.0439.. Test accuracy: 47.4375.. 0.0904 s/batch
# Epoch: 14/15.. Loss: 0.0715.. Test accuracy: 48.0625.. 0.0980 s/batch
# Epoch: 14/15.. Loss: 0.0539.. Test accuracy: 47.6875.. 0.0942 s/batch
# Epoch: 14/15.. Loss: 0.0636.. Test accuracy: 47.3125.. 0.0975 s/batch
# Epoch: 14/15.. Loss: 0.0523.. Test accuracy: 46.3750.. 0.0920 s/batch
# Epoch: 14/15.. Loss: 0.0600.. Test accuracy: 46.6250.. 0.0940 s/batch
# Epoch: 14/15.. Loss: 0.0606.. Test accuracy: 46.5625.. 0.0940 s/batch
# Epoch: 14/15.. Loss: 0.0453.. Test accuracy: 45.3125.. 0.0900 s/batch
# Epoch: 14/15.. Loss: 0.0556.. Test accuracy: 46.2500.. 0.0987 s/batch
# Epoch: 14/15.. Loss: 0.0580.. Test accuracy: 45.0000.. 0.0959 s/batch
# Epoch: 14/15.. Loss: 0.0568.. Test accuracy: 46.6250.. 0.0962 s/batch
# Epoch: 14/15.. Loss: 0.0643.. Test accuracy: 46.8125.. 0.0938 s/batch
# Epoch: 14/15.. Loss: 0.0592.. Test accuracy: 46.6250.. 0.0924 s/batch
# Epoch: 14/15.. Loss: 0.0708.. Test accuracy: 45.8125.. 0.1029 s/batch
# Epoch: 14/15.. Loss: 0.0691.. Test accuracy: 46.5000.. 0.0955 s/batch
# Epoch: 14/15.. Loss: 0.0840.. Test accuracy: 46.6250.. 0.0933 s/batch
# Epoch: 14/15.. Loss: 0.0699.. Test accuracy: 45.4375.. 0.0918 s/batch
# Epoch: 14/15.. Loss: 0.0814.. Test accuracy: 46.2500.. 0.0921 s/batch
# Epoch: 14/15.. Loss: 0.0686.. Test accuracy: 45.8750.. 0.0975 s/batch
# Epoch: 14/15.. Loss: 0.0838.. Test accuracy: 46.6250.. 0.0911 s/batch
# Epoch: 14/15.. Loss: 0.0704.. Test accuracy: 47.7500.. 0.0960 s/batch
# Epoch: 14/15.. Loss: 0.0731.. Test accuracy: 45.8125.. 0.0892 s/batch
# Epoch: 15/15.. Loss: 0.0477.. Test accuracy: 48.5000.. 0.0875 s/batch
# Epoch: 15/15.. Loss: 0.0607.. Test accuracy: 47.4375.. 0.0980 s/batch
# Epoch: 15/15.. Loss: 0.0630.. Test accuracy: 47.7500.. 0.0953 s/batch
# Epoch: 15/15.. Loss: 0.0723.. Test accuracy: 46.5000.. 0.0951 s/batch
# Epoch: 15/15.. Loss: 0.0506.. Test accuracy: 46.2500.. 0.0946 s/batch
# Epoch: 15/15.. Loss: 0.0375.. Test accuracy: 47.0000.. 0.0907 s/batch
# Epoch: 15/15.. Loss: 0.0400.. Test accuracy: 45.8125.. 0.0959 s/batch
# Epoch: 15/15.. Loss: 0.0532.. Test accuracy: 48.5000.. 0.0908 s/batch
# Epoch: 15/15.. Loss: 0.0502.. Test accuracy: 47.6250.. 0.0926 s/batch
# Epoch: 15/15.. Loss: 0.0463.. Test accuracy: 47.8125.. 0.0915 s/batch
# Epoch: 15/15.. Loss: 0.0454.. Test accuracy: 46.6875.. 0.0903 s/batch
# Epoch: 15/15.. Loss: 0.0586.. Test accuracy: 46.7500.. 0.0968 s/batch
# Epoch: 15/15.. Loss: 0.0706.. Test accuracy: 46.1875.. 0.0975 s/batch
# Epoch: 15/15.. Loss: 0.0582.. Test accuracy: 45.9375.. 0.0913 s/batch
# Epoch: 15/15.. Loss: 0.0598.. Test accuracy: 47.1875.. 0.0908 s/batch
# Epoch: 15/15.. Loss: 0.0448.. Test accuracy: 46.3125.. 0.0960 s/batch
# Epoch: 15/15.. Loss: 0.0536.. Test accuracy: 46.6250.. 0.0973 s/batch
# Epoch: 15/15.. Loss: 0.0478.. Test accuracy: 46.1250.. 0.0897 s/batch
# Epoch: 15/15.. Loss: 0.0453.. Test accuracy: 47.3750.. 0.0908 s/batch
# Epoch: 15/15.. Loss: 0.0366.. Test accuracy: 46.2500.. 0.0933 s/batch
# Epoch: 15/15.. Loss: 0.0516.. Test accuracy: 47.2500.. 0.0892 s/batch
# Epoch: 15/15.. Loss: 0.0508.. Test accuracy: 46.5000.. 0.0976 s/batch
# Epoch: 15/15.. Loss: 0.0455.. Test accuracy: 46.1250.. 0.0913 s/batch
# Epoch: 15/15.. Loss: 0.0608.. Test accuracy: 47.1250.. 0.0922 s/batch
# Epoch: 15/15.. Loss: 0.0540.. Test accuracy: 47.1875.. 0.0945 s/batch
# Epoch: 15/15.. Loss: 0.0708.. Test accuracy: 46.7500.. 0.1769 s/batch
# Epoch: 15/15.. Loss: 0.0376.. Test accuracy: 46.0625.. 0.2551 s/batch
# Epoch: 15/15.. Loss: 0.0674.. Test accuracy: 46.5625.. 0.1010 s/batch
# Epoch: 15/15.. Loss: 0.0887.. Test accuracy: 47.0625.. 0.0933 s/batch
# Epoch: 15/15.. Loss: 0.0603.. Test accuracy: 47.1250.. 0.1027 s/batch
# Epoch: 15/15.. Loss: 0.0823.. Test accuracy: 45.6250.. 0.0928 s/batch
# Epoch: 15/15.. Loss: 0.0538.. Test accuracy: 46.0625.. 0.0908 s/batch
# Epoch: 15/15.. Loss: 0.1142.. Test accuracy: 47.3125.. 0.0952 s/batch
# Epoch: 15/15.. Loss: 0.0780.. Test accuracy: 46.4375.. 0.0911 s/batch
# Epoch: 15/15.. Loss: 0.0935.. Test accuracy: 47.8125.. 0.0895 s/batch
# Epoch: 15/15.. Loss: 0.0867.. Test accuracy: 46.6250.. 0.0905 s/batch
# Epoch: 15/15.. Loss: 0.0896.. Test accuracy: 46.4375.. 0.0927 s/batch
# Epoch: 15/15.. Loss: 0.1003.. Test accuracy: 45.5625.. 0.1239 s/batch

# %% [markdown]
# Save best trained model.

# %%
## You should be familiar with how to save a pytorch model (Make sure to save the model in your Drive)
torch.save(net.state_dict(), './conv_net.pth')

# %% [markdown]
# # Some visualisations and Interpretation questions
# This code allows us to look at the filters of the first layer of convolution :

# %%
def visualize_filters(layer, title='Filters'):
    filters = layer.weight.data.clone().cpu()
    filters = (filters - filters.min()) / (filters.max() - filters.min())
    grid = vutils.make_grid(filters, nrow=8, padding=2)
    plt.figure(figsize=(8,8))
    plt.imshow(grid.permute(1, 2, 0))
    plt.title(title)
    plt.axis('off')
    plt.show()

model = ConvNet()

fig, axes = plt.subplots(1, 2, figsize=(16, 8))

# --- Untrained filters ---
filters_untrained = model.conv1.weight.data.clone().cpu()
filters_untrained = (filters_untrained - filters_untrained.min()) / (filters_untrained.max() - filters_untrained.min())
grid_untrained = vutils.make_grid(filters_untrained, nrow=8, padding=2)
axes[0].imshow(grid_untrained.permute(1, 2, 0))
axes[0].set_title("Block 1 - First Conv Filters (Untrained)")
axes[0].axis("off")

# --- Trained filters ---
filters_trained = net.conv1.weight.data.clone().cpu()
filters_trained = (filters_trained - filters_trained.min()) / (filters_trained.max() - filters_trained.min())
grid_trained = vutils.make_grid(filters_trained, nrow=8, padding=2)
axes[1].imshow(grid_trained.permute(1, 2, 0))
axes[1].set_title("Block 1 - First Conv Filters (Trained)")
axes[1].axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# #### What do you notice about the filters after the training ? Try to fin an interpretation about it.
#
# **Answer:** The trained filters appear dimmer than the initial filters. This is because the filters are learned during training, and the initial filters are random. The trained filters are more specialized to detect certain features in the images typically edges, corners, etc which correspond to darker regions in the filters.

# %% [markdown]
# ### Activation maps
# This code snippet uses a forward hook to capture the output of the first convolutional layer of a CNN when a sample image is passed through it. The resulting activation maps show how each filter in the layer responds to different regions or features in the image.

# %%
def get_activation(model, layer, x):
    activation = {}
    def hook_fn(module, input, output):
        activation['output'] = output.detach().cpu()
    hook = layer.register_forward_hook(hook_fn)
    model(x)
    hook.remove()
    return activation['output']

data_iter = iter(trainloader)
sample_images, sample_labels = next(data_iter)
sample_img = sample_images[0].unsqueeze(0)

# Get the feature maps after the first convolution (for example)
activation = get_activation(net, net.conv1, sample_img)

# Visualize a few feature maps in RGB:
def plot_feature_maps(feature_maps, n_cols=8):
    n_features = feature_maps.shape[1]
    n_rows = (n_features + n_cols - 1) // n_cols
    plt.figure(figsize=(n_cols * 1.5, n_rows * 1.5))
    for i in range(n_features):
        plt.subplot(n_rows, n_cols, i + 1)
        # Extract the i-th feature map from the first (and only) sample in the batch
        act = feature_maps[0, i, :, :]
        # Normalize the activation map to [0, 1]
        act_norm = (act - act.min()) / (act.max() - act.min() + 1e-8)
        # Repeat the single channel 3 times to form an RGB image
        act_rgb = act_norm.unsqueeze(0).repeat(3, 1, 1)
        plt.imshow(act_rgb.permute(1, 2, 0))
        plt.axis('off')
    plt.tight_layout()
    plt.show()

plot_feature_maps(activation, n_cols=8)

# Play with the index of the chosen sample to notice more patterns and answer the question

# %% [markdown]
# # **Theory - Part 2 (20%)**
#
# Please answer the following questions based on your experience/observation during the training and inference of a CNN.
#
# If you find any of these questions challenging or have any doubts, feel free to ask a TA for guidance or hints on the solution.

# %% [markdown]
# ## 5. Feature Detection
# What specific features do you observe in these activation maps? Do some maps clearly highlight edges, contours, or textures? How might these features relate to the overall structure of the sample (e.g., the outline of a horse)?

# %% [markdown]
# ## Ans5:
# The activation maps show the response of each filter in the first convolutional layer to different regions or features in the image. Some maps clearly highlight edges, contours, or textures. These features relate to the overall structure of the sample by detecting edges, corners, and other features that are important for recognizing objects in the image.

# %% [markdown]
# ## 6. Effect of Training
# Consider how the activations might change after training versus an untrained (random) network. What does this tell you about the learning process?

# %% [markdown]
# ## Ans6:
# The activations might change after training by becoming more specialized to detect certain features in the images. This tells us that the learning process involves adjusting the weights of the filters to detect specific features in the images.
