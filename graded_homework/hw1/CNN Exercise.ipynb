# %% [markdown]
# ## Convolutional Networks
#
# We'll check out how to build a **convolutional network** to classify CIFAR10 images. By using weight sharing - multiple units with the same weights - convolutional layers are able to learn repeated patterns in your data. For example, a unit could learn the pattern for an eye, or a face, or lower level features like edges.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\kelan\Desktop\MA4_DLAV\graded_homework\hw1\CNN Exercise.ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/kelan/Desktop/MA4_DLAV/graded_homework/hw1/CNN%20Exercise.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> from google.colab import drive
#       <a href='vscode-notebook-cell:/c%3A/Users/kelan/Desktop/MA4_DLAV/graded_homework/hw1/CNN%20Exercise.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> drive.mount('/content/drive')
#
# ModuleNotFoundError: No module named 'google'

# %%
import numpy as np
import time

import torch
from torch import nn
from torch import optim
import torch.nn.functional as F
import torch.utils.data as utils
from torchvision import datasets, transforms
from torch.utils.data.sampler import SubsetRandomSampler
import matplotlib.pyplot as plt
import torchvision.utils as vutils
from torchvision.datasets import CIFAR10

# %matplotlib inline

# %%
label_names = [
    'airplane',
    'automobile',
    'bird',
    'cat',
    'deer',
    'dog',
    'frog',
    'horse',
    'ship',
    'truck'
]


def plot_images(images, cls_true, cls_pred=None):
    """
    Adapted from https://github.com/Hvass-Labs/TensorFlow-Tutorials/
    """
    fig, axes = plt.subplots(3, 3)

    for i, ax in enumerate(axes.flat):
        # plot img
        ax.imshow(images[i, :, :, :], interpolation='spline16')

        # show true & predicted classes
        cls_true_name = label_names[cls_true[i]]
        if cls_pred is None:
            xlabel = "{0} ({1})".format(cls_true_name, cls_true[i])
        else:
            cls_pred_name = label_names[cls_pred[i]]
            xlabel = "True: {0}\nPred: {1}".format(
                cls_true_name, cls_pred_name
            )
        ax.set_xlabel(xlabel)
        ax.set_xticks([])
        ax.set_yticks([])

    plt.show()

# %%
def get_train_valid_loader(data_dir='data',
                           batch_size=64,
                           augment=False,
                           random_seed=1,
                           valid_size=0.02,
                           shuffle=True,
                           show_sample=True,
                           num_workers=4,
                           pin_memory=False):
    """
    Utility function for loading and returning train and valid
    multi-process iterators over the CIFAR-10 dataset. A sample
    9x9 grid of the images can be optionally displayed.
    If using CUDA, num_workers should be set to 1 and pin_memory to True.
    Params
    ------
    - data_dir: path directory to the dataset.
    - batch_size: how many samples per batch to load.
    - augment: whether to apply the data augmentation scheme
      mentioned in the paper. Only applied on the train split.
    - random_seed: fix seed for reproducibility.
    - valid_size: percentage split of the training set used for
      the validation set. Should be a float in the range [0, 1].
    - shuffle: whether to shuffle the train/validation indices.
    - show_sample: plot 9x9 sample grid of the dataset.
    - num_workers: number of subprocesses to use when loading the dataset.
    - pin_memory: whether to copy tensors into CUDA pinned memory. Set it to
      True if using GPU.
    Returns
    -------
    - train_loader: training set iterator.
    - valid_loader: validation set iterator.
    """
    error_msg = "[!] valid_size should be in the range [0, 1]."
    assert ((valid_size >= 0) and (valid_size <= 1)), error_msg

    normalize = transforms.Normalize(
        mean=[0.4914, 0.4822, 0.4465],
        std=[0.2023, 0.1994, 0.2010],
    )

    # define transforms for validation (no augmentation)
    valid_transform = transforms.Compose([
        transforms.ToTensor(),
        normalize,
    ])

    # Define the transform for training (and data augmentation)

    # train_transform = transforms.Compose([
    #     transforms.ToTensor(),
    #     normalize,
    # ])


    train_transform = transforms.Compose([
        transforms.RandomCrop(32, padding=4),  # Data Augmentation
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))  # Normalization
    ])
    

    # load the dataset
    train_dataset = datasets.CIFAR10(
        root=data_dir, train=True,
        download=True, transform=train_transform,
    )

    valid_dataset = datasets.CIFAR10(
        root=data_dir, train=True,
        download=True, transform=valid_transform,
    )

    num_train = len(train_dataset)
    indices = list(range(num_train))
    split = int(np.floor(valid_size * num_train))

    if shuffle:
        np.random.seed(random_seed)
        np.random.shuffle(indices)

    train_idx, valid_idx = indices[split:], indices[:split]
    train_sampler = SubsetRandomSampler(train_idx)
    valid_sampler = SubsetRandomSampler(valid_idx)

    train_loader = torch.utils.data.DataLoader(
        train_dataset, batch_size=batch_size, sampler=train_sampler,
        num_workers=num_workers, pin_memory=pin_memory,
    )
    valid_loader = torch.utils.data.DataLoader(
        valid_dataset, batch_size=batch_size, sampler=valid_sampler,
        num_workers=num_workers, pin_memory=pin_memory,
    )

    # visualize some images if requested
    if show_sample:
        sample_loader = torch.utils.data.DataLoader(
            train_dataset, batch_size=9, shuffle=shuffle,
            num_workers=num_workers, pin_memory=pin_memory,
        )
        data_iter = iter(sample_loader)
        images, labels = next(data_iter)
        # Unnormalize the images for display
        mean = [0.4914, 0.4822, 0.4465]
        std = [0.2023, 0.1994, 0.2010]
        unnorm_images = [unnormalize(img, mean, std) for img in images]
        X = torch.stack(unnorm_images).numpy().transpose([0, 2, 3, 1])
        plot_images(X, labels)

    return (train_loader, valid_loader)

def unnormalize(img, mean, std):
    img = img * torch.tensor(std).view(3, 1, 1) + torch.tensor(mean).view(3, 1, 1)
    return img

trainloader, valloader = get_train_valid_loader()

# %% [markdown]
# # Convolutional Neural Network Architecture

# %% [markdown]
# Please first review the CNN lecture and problem statement pdf to understand the overall architecture of a CNN and how each dimension evolves after each layer, we'll take as example the first and famous CNN LeNet5 :
# <figure align="center">
#   <img src="https://doimages.nyc3.cdn.digitaloceanspaces.com/010AI-ML/content/images/2021/10/image-17.png" alt="LeNet5 Architecture" width="600">
#   <figcaption>Image credit: <a href="https://en.wikipedia.org">Wikipedia</a></figcaption>
# </figure>

# %% [markdown]
# # **Theory - Part 1 (20%)**
#
# Please answer the following questions to assess your understanding of what happens during the training and inference of a CNN.
#
# If you find any of these questions challenging or have any doubts, feel free to ask a TA for guidance or hints on the solution.

# %% [markdown]
# ## 1. First Layer Convolution
#
# If we consider the input of LeNet5 to be CIFAR-10, what would be the shape of the parameters of the first convolutional layer (stride = 1)?
#
# - **A.** `torch.Size([6, 1, 5, 5])`
# - **B.** `torch.Size([6, 3, 3, 3])`
# - **C.** `torch.Size([6, 1, 5, 5])`
# - **D.** `torch.Size([6, 3, 5, 5])`

# %% [markdown]
# ## Ans1: D
# There are 6 output channels, 3 in channels (RGB) and a 5x5 kernal.

# %% [markdown]
# ## 2. Subsampling Window
#
# What is the shape of the subsampling window (stride = 2) for the second layer (between C1 and C2), and does this shape remain invariant regardless of the subsampling method (e.g., Avg pooling or Max pooling)?
#
# - **A.** `2x2, yes it does`
# - **B.** `3x3, no it doesn't`
# - **C.** `2x2, no it doesn't`
# - **D.** `yes, it does`

# %% [markdown]
# ## Ans2: A
# The choice of subsampling method changes the output but not the size

# %% [markdown]
# ## 3. Backpropagation for Convolutional Filters
#
# Do the filters in the convolutional layers also benefit from backpropagation?

# %% [markdown]
# ## Ans3: Yes
#
# The filters are parameters that can alse be learnt, therfore need backprop to update

# %% [markdown]
# ## 4. Role of the Fully-Connected Layer
#
# Explain in your own words why it is necessary to have a fully-connected layer in the architecture.

# %% [markdown]
# ## Ans4:
#
# The FC layer serves as the bridge between feature extraction and final decision-making. FC turn the high-level features from th eprevious feature extraction layers into scores that can be turned into class predictions.

# %% [markdown]
# # **Coding(60%)**
#
# ## Build your own Convolutional Neural Network Architecture

# %% [markdown]
# ## Different ways to improve the accuracy of your network :
# - Change the number of convolutions and layers (you can take inspiration from internet as you as you cite the architecture)
# - Change the optmizer / its hyperparameters
# - Add new types of layers
# - Do some data augmentation in the get_train_valid_loader function (flipped, cropped, uncentered images) cf. https://pytorch.org/vision/stable/transforms.html

# %%
class ConvNet(nn.Module):
    def __init__(self, n_input_channels=3, n_output=10):
        super().__init__()
        ################################################################################
        # TODO:                                                                        #
        # Define 2 or more different layers of the neural network                      #
        ################################################################################
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, padding=1)
        self.bn1 = nn.BatchNorm2d(64)
        self.conv2 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.bn2 = nn.BatchNorm2d(128)
        self.conv3 = nn.Conv2d(128, 256, kernel_size=3, padding=1)
        self.bn3 = nn.BatchNorm2d(256)
        self.conv4 = nn.Conv2d(256, 512, kernel_size=3, padding=1)
        self.bn4 = nn.BatchNorm2d(512)
        
        self.pool = nn.MaxPool2d(2, 2)
        self.dropout = nn.Dropout(0.25)
        
        self.fc1 = nn.Linear(512 * 2 * 2, 512)
        self.fc2 = nn.Linear(512, 128)
        self.fc3 = nn.Linear(128, 10)
    
        ################################################################################
        #                              END OF YOUR CODE                                #
        ################################################################################
    
    def forward(self, x):
        ################################################################################
        # TODO:                                                                        #
        # Set up the forward pass that the input data will go through.                 #
        # A good activation function betweent the layers is a ReLu function.           #
        #                                                                              #
        # Note that the output of the last convolution layer should be flattened       #
        # before being inputted to the fully connected layer. We can flatten           #
        # Tensor `x` with `x.view`.                                                    #
        ################################################################################
        x = self.pool(torch.relu(self.bn1(self.conv1(x))))
        x = self.pool(torch.relu(self.bn2(self.conv2(x))))
        x = self.pool(torch.relu(self.bn3(self.conv3(x))))
        x = self.pool(torch.relu(self.bn4(self.conv4(x))))

        x = self.dropout(x)
        
        x = torch.flatten(x, start_dim=1)
        x = torch.relu(self.fc1(x))
        x = self.dropout(x)
        x = torch.relu(self.fc2(x))
        x = self.dropout(x)
        x = self.fc3(x) 

        ################################################################################
        #                              END OF YOUR CODE                                #
        ################################################################################
        return x
    

    def predict(self, x):
        logits = self.forward(x)
        return F.softmax(logits)

# %%
import torch.optim


net = ConvNet()
################################################################################
# TODO:                                                                        #
# Choose an Optimizer that will be used to minimize the loss function.         #
# Choose a critera that measures the loss                                      #
################################################################################
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(net.parameters(), lr=0.001)

epochs = 15
steps = 0
running_loss = 0
print_every = 100
for e in range(epochs):
    start = time.time()
    for images, labels in iter(trainloader):

        steps += 1
        ################################################################################
        # TODO:                                                                        #
        # Run the training process                                                     #
        #                                                                              #
        #                                                                              #
        ################################################################################
        output = net(images)
        targets = labels
        ################################################################################
        #                              END OF YOUR CODE                                #
        ################################################################################

        loss = criterion(output, targets)
        ################################################################################
        # TODO:                                                                        #
        # Run the training process                                                     #
        #                                                                              #
        # HINT: Calculate the gradient and move one step further                       #
        ################################################################################
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        ################################################################################
        #                              END OF YOUR CODE                                #
        ################################################################################

        running_loss += loss.item()

        if steps % print_every == 0:
            stop = time.time()
            # Test accuracy
            accuracy = 0
            for ii, (images, labels) in enumerate(valloader):

                ################################################################################
                # TODO:                                                                        #
                # Calculate the accuracy                                                       #
                ################################################################################
                output = net(images)
                accuracy += torch.sum(torch.argmax(output, dim=1) == labels).item()
                ################################################################################
                #                              END OF YOUR CODE                                #
                ################################################################################

            print("Epoch: {}/{}..".format(e+1, epochs),
                  "Loss: {:.4f}..".format(running_loss/print_every),
                  "Test accuracy: {:.4f}..".format(accuracy/(ii+1)),
                  "{:.4f} s/batch".format((stop - start)/print_every)
                 )
            running_loss = 0
            start = time.time()

# goal : 50% accuracy
# 1 -> 45%
# 2 -> 47.2%
# 3 -> 52% (Data Augmentation, 15 epochs, batch norm + dropouts )
# Out:
# Epoch: 1/15.. Loss: 1.9441.. Test accuracy: 22.3125.. 0.2942 s/batch
# Epoch: 1/15.. Loss: 1.6918.. Test accuracy: 25.5000.. 0.1658 s/batch
# Epoch: 1/15.. Loss: 1.5461.. Test accuracy: 29.1875.. 0.1738 s/batch
# Epoch: 1/15.. Loss: 1.4882.. Test accuracy: 29.3125.. 0.1615 s/batch
# Epoch: 1/15.. Loss: 1.4041.. Test accuracy: 33.1875.. 0.1652 s/batch
# Epoch: 1/15.. Loss: 1.3290.. Test accuracy: 33.1875.. 0.1650 s/batch
# Epoch: 1/15.. Loss: 1.2862.. Test accuracy: 37.1250.. 0.1617 s/batch
# Epoch: 2/15.. Loss: 1.2292.. Test accuracy: 37.1875.. 0.2604 s/batch
# Epoch: 2/15.. Loss: 1.2099.. Test accuracy: 37.5000.. 0.1646 s/batch
# Epoch: 2/15.. Loss: 1.1516.. Test accuracy: 38.6875.. 0.1747 s/batch
# Epoch: 2/15.. Loss: 1.1322.. Test accuracy: 39.3750.. 0.1720 s/batch
# Epoch: 2/15.. Loss: 1.1215.. Test accuracy: 39.5000.. 0.1703 s/batch
# Epoch: 2/15.. Loss: 1.0464.. Test accuracy: 40.0625.. 0.1729 s/batch
# Epoch: 2/15.. Loss: 1.0383.. Test accuracy: 39.8750.. 0.1609 s/batch
# Epoch: 2/15.. Loss: 1.0447.. Test accuracy: 41.5625.. 0.1563 s/batch
# Epoch: 3/15.. Loss: 0.9961.. Test accuracy: 41.1875.. 0.2979 s/batch
# Epoch: 3/15.. Loss: 1.0078.. Test accuracy: 39.8125.. 0.1795 s/batch
# Epoch: 3/15.. Loss: 0.9623.. Test accuracy: 43.6250.. 0.1648 s/batch
# Epoch: 3/15.. Loss: 0.9259.. Test accuracy: 42.0000.. 0.1795 s/batch
# Epoch: 3/15.. Loss: 0.9455.. Test accuracy: 42.4375.. 0.1622 s/batch
# Epoch: 3/15.. Loss: 0.9114.. Test accuracy: 42.0000.. 0.1696 s/batch
# Epoch: 3/15.. Loss: 0.9381.. Test accuracy: 42.3750.. 0.1659 s/batch
# Epoch: 4/15.. Loss: 0.8832.. Test accuracy: 44.3125.. 0.2102 s/batch
# Epoch: 4/15.. Loss: 0.9036.. Test accuracy: 43.1250.. 0.1671 s/batch
# Epoch: 4/15.. Loss: 0.8797.. Test accuracy: 43.7500.. 0.1664 s/batch
# Epoch: 4/15.. Loss: 0.8657.. Test accuracy: 44.6875.. 0.1723 s/batch
# Epoch: 4/15.. Loss: 0.8393.. Test accuracy: 45.8750.. 0.1686 s/batch
# Epoch: 4/15.. Loss: 0.8142.. Test accuracy: 46.1875.. 0.1674 s/batch
# Epoch: 4/15.. Loss: 0.8503.. Test accuracy: 45.0625.. 0.1549 s/batch
# Epoch: 4/15.. Loss: 0.8385.. Test accuracy: 46.0625.. 0.1662 s/batch
# Epoch: 5/15.. Loss: 0.8024.. Test accuracy: 44.9375.. 0.2589 s/batch
# Epoch: 5/15.. Loss: 0.7660.. Test accuracy: 45.8750.. 0.1644 s/batch
# Epoch: 5/15.. Loss: 0.7641.. Test accuracy: 47.3750.. 0.1662 s/batch
# Epoch: 5/15.. Loss: 0.8073.. Test accuracy: 46.3750.. 0.1657 s/batch
# Epoch: 5/15.. Loss: 0.7820.. Test accuracy: 46.9375.. 0.1670 s/batch
# Epoch: 5/15.. Loss: 0.7760.. Test accuracy: 48.5625.. 0.1664 s/batch
# Epoch: 5/15.. Loss: 0.7474.. Test accuracy: 45.8750.. 0.1671 s/batch
# Epoch: 5/15.. Loss: 0.7535.. Test accuracy: 46.8750.. 0.1659 s/batch
# Epoch: 6/15.. Loss: 0.7200.. Test accuracy: 48.0625.. 0.3225 s/batch
# Epoch: 6/15.. Loss: 0.7397.. Test accuracy: 46.1875.. 0.1623 s/batch
# Epoch: 6/15.. Loss: 0.7204.. Test accuracy: 47.0625.. 0.1714 s/batch
# Epoch: 6/15.. Loss: 0.7514.. Test accuracy: 46.8125.. 0.1849 s/batch
# Epoch: 6/15.. Loss: 0.7154.. Test accuracy: 47.4375.. 0.1633 s/batch
# Epoch: 6/15.. Loss: 0.6985.. Test accuracy: 48.4375.. 0.1810 s/batch
# Epoch: 6/15.. Loss: 0.7167.. Test accuracy: 46.5000.. 0.1737 s/batch
# Epoch: 7/15.. Loss: 0.7097.. Test accuracy: 48.2500.. 0.2136 s/batch
# Epoch: 7/15.. Loss: 0.6689.. Test accuracy: 47.6875.. 0.1677 s/batch
# Epoch: 7/15.. Loss: 0.6709.. Test accuracy: 47.7500.. 0.1674 s/batch
# Epoch: 7/15.. Loss: 0.6659.. Test accuracy: 48.3750.. 0.1676 s/batch
# Epoch: 7/15.. Loss: 0.6699.. Test accuracy: 47.5625.. 0.1681 s/batch
# Epoch: 7/15.. Loss: 0.6734.. Test accuracy: 49.9375.. 0.1671 s/batch
# Epoch: 7/15.. Loss: 0.6538.. Test accuracy: 48.3750.. 0.1657 s/batch
# Epoch: 7/15.. Loss: 0.6686.. Test accuracy: 48.1875.. 0.1692 s/batch
# Epoch: 8/15.. Loss: 0.6495.. Test accuracy: 49.0000.. 0.2656 s/batch
# Epoch: 8/15.. Loss: 0.6178.. Test accuracy: 49.1250.. 0.1710 s/batch
# Epoch: 8/15.. Loss: 0.6534.. Test accuracy: 49.1875.. 0.1645 s/batch
# Epoch: 8/15.. Loss: 0.6345.. Test accuracy: 48.5625.. 0.1428 s/batch
# Epoch: 8/15.. Loss: 0.6263.. Test accuracy: 49.6250.. 0.1661 s/batch
# Epoch: 8/15.. Loss: 0.6304.. Test accuracy: 49.6875.. 0.1673 s/batch
# Epoch: 8/15.. Loss: 0.6161.. Test accuracy: 50.1250.. 0.1685 s/batch
# Epoch: 8/15.. Loss: 0.6413.. Test accuracy: 49.4375.. 0.1664 s/batch
# Epoch: 9/15.. Loss: 0.5863.. Test accuracy: 49.8125.. 0.3184 s/batch
# Epoch: 9/15.. Loss: 0.6067.. Test accuracy: 50.1250.. 0.1655 s/batch
# Epoch: 9/15.. Loss: 0.6068.. Test accuracy: 50.1875.. 0.1687 s/batch
# Epoch: 9/15.. Loss: 0.6163.. Test accuracy: 49.3125.. 0.1693 s/batch
# Epoch: 9/15.. Loss: 0.5963.. Test accuracy: 49.6250.. 0.1591 s/batch
# Epoch: 9/15.. Loss: 0.5736.. Test accuracy: 49.5000.. 0.1666 s/batch
# Epoch: 9/15.. Loss: 0.6074.. Test accuracy: 49.6875.. 0.1607 s/batch
# Epoch: 10/15.. Loss: 0.5866.. Test accuracy: 50.5000.. 0.2178 s/batch
# Epoch: 10/15.. Loss: 0.5626.. Test accuracy: 49.1875.. 0.1626 s/batch
# Epoch: 10/15.. Loss: 0.5801.. Test accuracy: 49.2500.. 0.1302 s/batch
# Epoch: 10/15.. Loss: 0.5489.. Test accuracy: 50.1875.. 0.1693 s/batch
# Epoch: 10/15.. Loss: 0.5733.. Test accuracy: 49.5000.. 0.1653 s/batch
# Epoch: 10/15.. Loss: 0.5745.. Test accuracy: 49.8125.. 0.1613 s/batch
# Epoch: 10/15.. Loss: 0.5593.. Test accuracy: 50.6250.. 0.1665 s/batch
# Epoch: 10/15.. Loss: 0.5625.. Test accuracy: 50.1250.. 0.1635 s/batch
# Epoch: 11/15.. Loss: 0.5415.. Test accuracy: 52.1250.. 0.2636 s/batch
# Epoch: 11/15.. Loss: 0.5263.. Test accuracy: 50.3750.. 0.1795 s/batch
# Epoch: 11/15.. Loss: 0.5351.. Test accuracy: 50.5000.. 0.1644 s/batch
# Epoch: 11/15.. Loss: 0.5267.. Test accuracy: 50.6875.. 0.1629 s/batch
# Epoch: 11/15.. Loss: 0.5185.. Test accuracy: 51.4375.. 0.1645 s/batch
# Epoch: 11/15.. Loss: 0.5557.. Test accuracy: 51.3750.. 0.1613 s/batch
# Epoch: 11/15.. Loss: 0.5070.. Test accuracy: 50.4375.. 0.1614 s/batch
# Epoch: 11/15.. Loss: 0.5521.. Test accuracy: 50.6250.. 0.1645 s/batch
# Epoch: 12/15.. Loss: 0.5005.. Test accuracy: 51.6250.. 0.2699 s/batch
# Epoch: 12/15.. Loss: 0.5038.. Test accuracy: 51.3125.. 0.1635 s/batch
# Epoch: 12/15.. Loss: 0.5330.. Test accuracy: 51.4375.. 0.1610 s/batch
# Epoch: 12/15.. Loss: 0.5072.. Test accuracy: 50.5000.. 0.1647 s/batch
# Epoch: 12/15.. Loss: 0.5234.. Test accuracy: 50.6250.. 0.1615 s/batch
# Epoch: 12/15.. Loss: 0.5145.. Test accuracy: 51.2500.. 0.1629 s/batch
# Epoch: 12/15.. Loss: 0.4907.. Test accuracy: 51.3750.. 0.1688 s/batch
# Epoch: 13/15.. Loss: 0.5035.. Test accuracy: 51.0000.. 0.2204 s/batch
# Epoch: 13/15.. Loss: 0.4700.. Test accuracy: 51.1250.. 0.1578 s/batch
# Epoch: 13/15.. Loss: 0.4961.. Test accuracy: 51.6250.. 0.1605 s/batch
# Epoch: 13/15.. Loss: 0.4539.. Test accuracy: 50.8750.. 0.1721 s/batch
# Epoch: 13/15.. Loss: 0.4862.. Test accuracy: 51.3125.. 0.1680 s/batch
# Epoch: 13/15.. Loss: 0.5052.. Test accuracy: 51.7500.. 0.1612 s/batch
# Epoch: 13/15.. Loss: 0.4945.. Test accuracy: 51.7500.. 0.1607 s/batch
# Epoch: 13/15.. Loss: 0.4933.. Test accuracy: 52.4375.. 0.1567 s/batch
# Epoch: 14/15.. Loss: 0.4639.. Test accuracy: 52.0000.. 0.2552 s/batch
# Epoch: 14/15.. Loss: 0.4789.. Test accuracy: 51.8125.. 0.1603 s/batch
# Epoch: 14/15.. Loss: 0.4789.. Test accuracy: 51.2500.. 0.1614 s/batch
# Epoch: 14/15.. Loss: 0.4774.. Test accuracy: 51.6875.. 0.1610 s/batch
# Epoch: 14/15.. Loss: 0.4640.. Test accuracy: 51.8125.. 0.1610 s/batch
# Epoch: 14/15.. Loss: 0.4505.. Test accuracy: 51.5625.. 0.1605 s/batch
# Epoch: 14/15.. Loss: 0.4782.. Test accuracy: 51.2500.. 0.1607 s/batch
# Epoch: 14/15.. Loss: 0.4646.. Test accuracy: 52.0000.. 0.1610 s/batch
# Epoch: 15/15.. Loss: 0.4234.. Test accuracy: 53.3750.. 0.3149 s/batch
# Epoch: 15/15.. Loss: 0.4494.. Test accuracy: 51.6250.. 0.1762 s/batch
# Epoch: 15/15.. Loss: 0.4553.. Test accuracy: 51.1250.. 0.1682 s/batch
# Epoch: 15/15.. Loss: 0.4571.. Test accuracy: 51.6875.. 0.1632 s/batch
# Epoch: 15/15.. Loss: 0.4390.. Test accuracy: 51.8125.. 0.1653 s/batch
# Epoch: 15/15.. Loss: 0.4738.. Test accuracy: 51.6250.. 0.1605 s/batch
# Epoch: 15/15.. Loss: 0.4701.. Test accuracy: 52.0000.. 0.1499 s/batch

# %% [markdown]
# Save best trained model.

# %%
## You should be familiar with how to save a pytorch model (Make sure to save the model in your Drive)
torch.save(net.state_dict(), './models/conv_net3.pth')

# %% [markdown]
# # Some visualisations and Interpretation questions
# This code allows us to look at the filters of the first layer of convolution :

# %%
def visualize_filters(layer, title='Filters'):
    filters = layer.weight.data.clone().cpu()
    filters = (filters - filters.min()) / (filters.max() - filters.min())
    grid = vutils.make_grid(filters, nrow=8, padding=2)
    plt.figure(figsize=(8,8))
    plt.imshow(grid.permute(1, 2, 0))
    plt.title(title)
    plt.axis('off')
    plt.show()

model = ConvNet() # Untrained model

fig, axes = plt.subplots(1, 2, figsize=(16, 8))

# --- Untrained filters ---
filters_untrained = model.conv1.weight.data.clone().cpu()
filters_untrained = (filters_untrained - filters_untrained.min()) / (filters_untrained.max() - filters_untrained.min())
grid_untrained = vutils.make_grid(filters_untrained, nrow=8, padding=2)
axes[0].imshow(grid_untrained.permute(1, 2, 0))
axes[0].set_title("Block 1 - First Conv Filters (Untrained)")
axes[0].axis("off")

# --- Trained filters ---
filters_trained = net.conv1.weight.data.clone().cpu()
filters_trained = (filters_trained - filters_trained.min()) / (filters_trained.max() - filters_trained.min())
grid_trained = vutils.make_grid(filters_trained, nrow=8, padding=2)
axes[1].imshow(grid_trained.permute(1, 2, 0))
axes[1].set_title("Block 1 - First Conv Filters (Trained)")
axes[1].axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# #### What do you notice about the filters after the training ? Try to fin an interpretation about it.

# %% [markdown]
# ### Activation maps
# This code snippet uses a forward hook to capture the output of the first convolutional layer of a CNN when a sample image is passed through it. The resulting activation maps show how each filter in the layer responds to different regions or features in the image.

# %%
def get_activation(model, layer, x):
    activation = {}
    def hook_fn(module, input, output):
        activation['output'] = output.detach().cpu()
    hook = layer.register_forward_hook(hook_fn)
    model(x)
    hook.remove()
    return activation['output']

data_iter = iter(trainloader)
sample_images, sample_labels = next(data_iter)
sample_img = sample_images[0].unsqueeze(0)

# Get the feature maps after the first convolution (for example)
activation = get_activation(net, net.conv1, sample_img)

# Visualize a few feature maps in RGB:
def plot_feature_maps(feature_maps, n_cols=8):
    n_features = feature_maps.shape[1]
    n_rows = (n_features + n_cols - 1) // n_cols
    plt.figure(figsize=(n_cols * 1.5, n_rows * 1.5))
    for i in range(n_features):
        plt.subplot(n_rows, n_cols, i + 1)
        # Extract the i-th feature map from the first (and only) sample in the batch
        act = feature_maps[0, i, :, :]
        # Normalize the activation map to [0, 1]
        act_norm = (act - act.min()) / (act.max() - act.min() + 1e-8)
        # Repeat the single channel 3 times to form an RGB image
        act_rgb = act_norm.unsqueeze(0).repeat(3, 1, 1)
        plt.imshow(act_rgb.permute(1, 2, 0))
        plt.axis('off')
    plt.tight_layout()
    plt.show()

plot_feature_maps(activation, n_cols=8)

# Play with the index of the chosen sample to notice more patterns and answer the question

# %% [markdown]
# # **Theory - Part 2 (20%)**
#
# Please answer the following questions based on your experience/observation during the training and inference of a CNN.
#
# If you find any of these questions challenging or have any doubts, feel free to ask a TA for guidance or hints on the solution.

# %% [markdown]
# ## 5. Feature Detection
# What specific features do you observe in these activation maps? Do some maps clearly highlight edges, contours, or textures? How might these features relate to the overall structure of the sample (e.g., the outline of a horse)?

# %% [markdown]
# ## Ans5:

# %% [markdown]
# ## 6. Effect of Training
# Consider how the activations might change after training versus an untrained (random) network. What does this tell you about the learning process?

# %% [markdown]
# ## Ans6:
